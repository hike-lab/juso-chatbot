# %%
import os
from literalai import LiteralClient
from literalai.filter import threads_filters as LiteralThreadsFilters

client = LiteralClient(api_key=os.getenv("LITERAL_API_KEY"))
# client = LiteralClient(api_key='lsk_W8SYhRc1CsluWTc1ObYZF8YFEjQm9TLUyUXUrKubY4')

# %%
has_next_page = True
after = None

filters = [
    {
        "field": "createdAt",
        "operator": "gte",
        "value": "2024-03-06T01:00:00.000Z"
    }
]

order_by = {
    "column": "createdAt",
    "direction": "DESC"
}
    
while has_next_page:
    response = client.api.get_threads(
        filters=filters,
        order_by=order_by,
        after=after
    )
    print(response.to_dict())
    has_next_page = response.pageInfo.hasNextPage
    after = response.pageInfo.endCursor
# Out:
# {'pageInfo': {'hasNextPage': False, 'startCursor': 'R1BDOlM6OWNiMTQ2MmItYTczZC00ZTJiLWI3MGUtMTE2ZWM5YWYyZTQ0', 'endCursor': 'R1BDOlM6NDhiYmYyYWYtZmM0OS00NDQxLTg5ZGItMjdlNjg0YWNiMTJl'}, 'totalCount': 8, 'data': [{'id': '9cb1462b-a73d-4e2b-b70e-116ec9af2e44', 'metadata': {}, 'tags': None, 'name': '특례시가 뭐야?', 'steps': [{'id': '33b8fb10-e5c2-4333-8f48-9f336c5f39ee', 'metadata': {'language': None, 'showInput': None, 'waitForAnswer': False}, 'parentId': None, 'startTime': '2024-08-07T04:11:42.927', 'endTime': '2024-08-07T04:11:42.927', 'type': 'user_message', 'threadId': '9cb1462b-a73d-4e2b-b70e-116ec9af2e44', 'error': None, 'input': None, 'output': {'content': '특례시가 뭐야?'}, 'generation': None, 'name': 'User', 'tags': None, 'scores': [], 'attachments': []}, {'id': 'db5c5138-50d7-4b2b-a6c8-782b65725827', 'metadata': {'language': None, 'showInput': 'json', 'waitForAnswer': None}, 'parentId': '33b8fb10-e5c2-4333-8f48-9f336c5f39ee', 'startTime': '2024-08-07T04:11:42.929', 'endTime': '2024-08-07T04:11:49.582', 'type': 'run', 'threadId': '9cb1462b-a73d-4e2b-b70e-116ec9af2e44', 'error': None, 'input': {'content': '특례시가 뭐야?'}, 'output': None, 'generation': None, 'name': 'on_message', 'tags': None, 'scores': [], 'attachments': []}, {'id': 'a4861cb3-4645-41ea-938c-361d2bd28198', 'metadata': {'language': None, 'showInput': 'json', 'waitForAnswer': None}, 'parentId': 'db5c5138-50d7-4b2b-a6c8-782b65725827', 'startTime': '2024-08-07T04:11:42.976', 'endTime': '2024-08-07T04:11:49.554', 'type': 'run', 'threadId': '9cb1462b-a73d-4e2b-b70e-116ec9af2e44', 'error': None, 'input': {'content': '특례시가 뭐야?'}, 'output': {'content': '[\n    {\n        "decision_maker": {\n            "question": "특례시가 뭐야?",\n            "q_type": "일반 질문"\n        }\n    },\n    {\n        "general_llm": {\n            "question": "특례시가 뭐야?",\n            "answer": "특례시는 특정한 법적 지위나 혜택을 부여받는 도시를 의미합니다. 대한민국에서는 인구 50만 명 이상인 도시 중에서 특별한 행정적, 재정적 권한을 부여받는 도시를 특례시라고 합니다. 특례시는 일반 시보다 더 많은 자치권과 재정적 지원을 받을 수 있으며, 이를 통해 지역 발전과 주민 복지를 증진시키는 것을 목표로 합니다. 예를 들어, 수원시, 고양시, 용인시, 창원시 등이 특례시로 지정되어 있습니다."\n        }\n    }\n]'}, 'generation': None, 'name': 'langgraph', 'tags': None, 'scores': [], 'attachments': []}, {'id': 'c104c89e-db1c-4752-9840-802cbce74b50', 'metadata': {'language': None, 'showInput': None, 'waitForAnswer': False}, 'parentId': 'db5c5138-50d7-4b2b-a6c8-782b65725827', 'startTime': '2024-08-07T04:11:49.571', 'endTime': '2024-08-07T04:11:49.571', 'type': 'assistant_message', 'threadId': '9cb1462b-a73d-4e2b-b70e-116ec9af2e44', 'error': None, 'input': None, 'output': {'content': '특례시는 특정한 법적 지위나 혜택을 부여받는 도시를 의미합니다. 대한민국에서는 인구 50만 명 이상인 도시 중에서 특별한 행정적, 재정적 권한을 부여받는 도시를 특례시라고 합니다. 특례시는 일반 시보다 더 많은 자치권과 재정적 지원을 받을 수 있으며, 이를 통해 지역 발전과 주민 복지를 증진시키는 것을 목표로 합니다. 예를 들어, 수원시, 고양시, 용인시, 창원시 등이 특례시로 지정되어 있습니다.'}, 'generation': None, 'name': 'Address Chatbot', 'tags': None, 'scores': [], 'attachments': []}], 'participant': {}, 'createdAt': '2024-08-07T04:11:50.001Z'}, {'id': '20ae5a94-28a9-4be9-b499-1c8543e5fcf8', 'metadata': {'client_type': 'webapp', 'chat_profile': None, 'http_referer': 'https://0e91-124-49-193-154.ngrok-free.app/', 'chat_settings': {}}, 'tags': None, 'name': None, 'steps': [{'id': 'e68f5e26-da41-489e-a24a-d06ba293a456', 'metadata': {}, 'parentId': None, 'startTime': '2024-08-07T04:08:56.328', 'endTime': '2024-08-07T04:09:06.468', 'type': 'undefined', 'threadId': '20ae5a94-28a9-4be9-b499-1c8543e5fcf8', 'error': None, 'input': None, 'output': None, 'generation': None, 'name': '', 'tags': None, 'scores': [], 'attachments': []}, {'id': '13c63075-83b1-4cb3-ae88-663988e31ee8', 'metadata': {'language': None, 'showInput': 'json', 'waitForAnswer': None}, 'parentId': 'e68f5e26-da41-489e-a24a-d06ba293a456', 'startTime': '2024-08-07T04:08:56.328', 'endTime': '2024-08-07T04:09:06.468', 'type': 'run', 'threadId': '20ae5a94-28a9-4be9-b499-1c8543e5fcf8', 'error': None, 'input': {'content': '도로명주소의 정의를 알려줘'}, 'output': None, 'generation': None, 'name': 'on_message', 'tags': None, 'scores':  ...

# %%
response
# Out:
# {
#     "data": [
#         {
#             "createdAt": "2024-08-02T09:07:57.355Z",
#             "id": "a115f2c1-9b90-47fc-b73f-9034ac4dc697",
#             "metadata": {
#                 "chat_profile": null,
#                 "chat_settings": {},
#                 "client_type": "webapp",
#                 "http_referer": "http://localhost:8000/"
#             },
#             "name": "\ub3c4\ub85c\uba85\uc8fc\uc18c\uc758 \ud615\uc2dd\uc744 \uc54c\ub824\uc918",
#             "participant": {},
#             "steps": [
#                 {
#                     "attachments": [],
#                     "endTime": "2024-08-02T09:07:48.662",
#                     "error": null,
#                     "generation": null,
#                     "id": "3cd03083-b35e-4a77-9448-796a783cafaf",
#                     "input": null,
#                     "metadata": {
#                         "language": null,
#                         "showInput": null,
#                         "waitForAnswer": false
#                     },
#                     "name": "User",
#                     "output": {
#                         "content": "\ub3c4\ub85c\uba85\uc8fc\uc18c\uc758 \ud615\uc2dd\uc744 \uc54c\ub824\uc918"
#                     },
#                     "parentId": null,
#                     "scores": [],
#                     "startTime": "2024-08-02T09:07:48.662",
#                     "tags": null,
#                     "threadId": "a115f2c1-9b90-47fc-b73f-9034ac4dc697",
#                     "type": "user_message"
#                 },
#                 {
#                     "attachments": [],
#                     "endTime": "2024-08-02T09:07:57.024",
#                     "error": null,
#                     "generation": null,
#                     "id": "cdb47dda-eae6-4e01-82e6-0a52746da9c6",
#                     "input": {
#                         "content": "\ub3c4\ub85c\uba85\uc8fc\uc18c\uc758 \ud615\uc2dd\uc744 \uc54c\ub824\uc918"
#                     },
#                     "metadata": {
#                         "language": null,
#                         "showInput": "json",
#                         "waitForAnswer": null
#                     },
#                     "name": "on_message",
#                     "output": null,
#                     "parentId": "3cd03083-b35e-4a77-9448-796a783cafaf",
#                     "scores": [],
#                     "startTime": "2024-08-02T09:07:48.665",
#                     "tags": null,
#                     "threadId": "a115f2c1-9b90-47fc-b73f-9034ac4dc697",
#                     "type": "run"
#                 },
#                 {
#                     "attachments": [],
#                     "endTime": "2024-08-02T09:07:57.009",
#                     "error": null,
#                     "generation": null,
#                     "id": "2d8db534-dcdb-4230-888a-8257edf22784",
#                     "input": null,
#                     "metadata": {
#                         "language": null,
#                         "showInput": null,
#                         "waitForAnswer": false
#                     },
#                     "name": "Assistant",
#                     "output": {
#                         "content": "\ub3c4\ub85c\uba85\uc8fc\uc18c\uc758 \ud615\uc2dd\uc740 \ub3c4\ub85c\uba85\uc8fc\uc18c\ubc95 \uc2dc\ud589\ub839 \uc81c6\uc870\uc5d0 \ub530\ub77c \uad6c\uc131\uacfc \ud45c\uae30 \ubc29\ubc95\uc744 \uc900\uc218\ud574\uc57c \ud569\ub2c8\ub2e4. \ub3c4\ub85c\uba85\uc8fc\uc18c\ub294 \ud55c\uae00\uacfc \uc601\ubb38\uc73c\ub85c \ud45c\uae30\ub420 \uc218 \uc788\uc73c\uba70, \uc0c1\uc138\uc8fc\uc18c\uc640 \uc0ac\ubb3c\uc8fc\uc18c, \ub3c4\ub85c\uba85 \ub4f1\uc774 \ud3ec\ud568\ub429\ub2c8\ub2e4. \n\n\ucd9c\ucc98: final/chapter-3-3"
#                     },
#                     "parentId": "cdb47dda-eae6-4e01-82e6-0a52746da9c6",
#                     "scores": [],
#                     "startTime": "2024-08-02T09:07:57.009",
#                     "tags": null,
#                     "threadId": "a115f2c1-9b90-47fc-b73f-9034ac4dc697",
#                     "type": "assistant_message"
#                 }
#             ],
#             "tags": null
#         },
#         {
#             "createdAt": "2024-08-02T08:55:46.799Z",
#             "id": "19b3cd31-4cf9-40f3-b593-f99c2c4ec840",
#             "metadata": {
#                 "chat_profile": null,
#                 "chat_settings": {},
#                 "client_type": "webapp",
#                 "http_referer": "http://localhost:8000/"
#             },
#             "name": null,
#             "participant": {},
#             "steps": [
#                 {
#                     "attachments": [],
#                     "endTime": "2024-08-02T08:55:46.385",
#                     "error": null,
#                     "generation": null,
#                     "id": "bc1263b8-8511-4eb0-bbd6-59833ea506ce",
#                     "input": null,
#                     "metadata": {},
#                     "name": "",
#                     "output": null,
#                     "parentId": null,
#                     "scores": [],
#                     "startTime": "2024-08-02T08:55:32.715",
#                     "tags": null,
#                     "threadId": "19b3cd31-4cf9-40f3-b593-f99c2c4ec840",
#                     "type": "undefined"
#                 },
#                 {
#                     "attachments": [],
#                     "endTime": "2024-08-02T08:55:46.385",
#                     "error": null,
#                     "generation": null,
#                     "id": "08ad7357-4cf9-4a70-a144-2c02fe900728",
#                     "input": {
#                         "content": "\ud55c\uad6d\ud615 \ub3c4\ub85c\uba85\uc8fc\uc18c\ub780 \ubb58\uae4c?"
#                     },
#                     "metadata": {
#                         "language": null,
#                         "showInput": "json",
#                         "waitForAnswer": null
#                     },
#                     "name": "on_message",
#                     "output": null,
#                     "parentId": "bc1263b8-8511-4eb0-bbd6-59833ea506ce",
#                     "scores": [],
#                     "startTime": "2024-08-02T08:55:32.715",
#                     "tags": null,
#                     "threadId": "19b3cd31-4cf9-40f3-b593-f99c2c4ec840",
#                     "type": "run"
#                 },
#                 {
#                     "attachments": [],
#                     "endTime": "2024-08-02T08:55:46.367",
#                     "error": null,
#                     "generation": null,
#                     "id": "be39bce8-4ac2-4cbd-8538-5077a597e08e",
#                     "input": null,
#                     "metadata": {
#                         "language": null,
#                         "showInput": null,
#                         "waitForAnswer": false
#                     },
#                     "name": "Assistant",
#                     "output": {
#                         "content": "\ud55c\uad6d\ud615 \ub3c4\ub85c\uba85\uc8fc\uc18c\ub294 2014\ub144\uc5d0 \uae30\uc874\uc758 \uc9c0\ubc88\uc8fc\uc18c\uc5d0\uc11c \ub3c4\ub85c\uba85\uc8fc\uc18c\ub85c \uc804\uba74 \uac1c\ud3b8\ub41c \uc8fc\uc18c\uccb4\uacc4\ub97c \ub9d0\ud569\ub2c8\ub2e4. \uc774\ud6c4 \ub3c4\ub85c\uba85\uc8fc\uc18c\ubfd0\ub9cc \uc544\ub2c8\ub77c \uc0ac\ubb3c\uc8fc\uc18c, \uacf5\uac04\uc8fc\uc18c \ub4f1 \ub2e4\uc591\ud55c \uc720\ud615\uc774 \uac1c\ubc1c\ub418\uc5c8\uc73c\uba70, \uc8fc\uc18c\uc758 \ubd80\uc5ec \ubc94\uc704\ub3c4 \uac74\ucd95\ubb3c\uc744 \ub118\uc5b4 \uc0ac\ubb3c, \ud574\uc548\u00b7\ud574\uc591\uc73c\ub85c \uc810\ucc28 \ud655\ub300\ub418\uace0 \uc788\uc2b5\ub2c8\ub2e4. \uc774 \uc8fc\uc18c\uccb4\uacc4\ub294 \ub3c4\ub85c\uba85\uc8fc\uc18c\ubc95\uc744 \ubc95\ub960\uc801 \uadfc\uac70\ub85c \ud558\uc5ec \uad6d\uac00\uc8fc\uc18c\uc815\ubcf4\uc2dc\uc2a4\ud15c\uc744 \ud1b5\ud574 \uad00\ub9ac\ub418\uba70, \uc8fc\uc18c\uc815\ubcf4\ub204\ub9ac\uc9d1\uacfc \uc8fc\uc18c\uae30\ubc18\uc0b0\uc5c5\uc9c0\uc6d0\uc11c\ube44\uc2a4\ub97c \ud1b5\ud574 \uacf5\uacf5 \ubc0f \ubbfc\uac04\uc5d0\uc11c \ud65c\uc6a9\ub418\uace0 \uc788\uc2b5\ub2c8\ub2e4. \ud589\uc815\uc548\uc804\ubd80\ub294 \uc8fc\uc18c\ub97c '\ud604\uc2e4\uacfc \uac00\uc0c1\uc138\uacc4\ub97c \uc5f0\uacb0\ud558\ub294 \ub9e4\uac1c\uccb4'\ub85c \uc815\uc758\ud558\uace0, \uc8fc\uc18c\uc758 \ub370\uc774\ud130 \uac00\uce58\ub97c \ud655\ub300\ud558\uae30 \uc704\ud574 \ub178\ub825\ud558\uace0 \uc788\uc2b5\ub2c8\ub2e4. \n\n\ucd9c\ucc98: final/ISO 19160-1-2015 \u1100\u1162\u1102\u1167\u11b7\u1106\u1169\u1103\u1166\u11af\u110b\u1166 \u1103\u1162\u1112\u1161\u11ab \u1107\u116e\u11ab\u1109\u1165\u11a8\u1100\u116a \u110b\u1175\u1112\u1162"
#                     },
#                     "parentId": "08ad7357-4cf9-4a70-a144-2c02fe900728",
#                     "scores": [],
#                     "startTime": "2024-08-02T08:55:46.367",
#                     "tags": null,
#                     "threadId": "19b3cd31-4cf9-40f3-b593-f99c2c4ec840",
#                     "type": "assistant_message"
#                 }
#             ],
#             "tags": null
#         },
#         {
#             "createdAt": "2024-08-02T08:53:18.253Z",
#             "id": "46eb61fa-af7c-4a2c-9ce9-bef6f1ac7e5d",
#             "metadata": {
#                 "chat_profile": null,
#                 "chat_settings": {},
#                 "client_type": "webapp",
#                 "http_referer": "http://localhost:8000/"
#             },
#             "name": "\ud55c\uad6d\ud615 \ub3c4\ub85c\uba85\uc8fc\uc18c\ub780 \ubb58\uae4c?",
#             "participant": {
#                 "id": "d2ad291c-0975-45d4-9407-77930d045ca7",
#                 "identifier": "cathx618@gmail.com"
#             },
#             "steps": [
#                 {
#                     "attachments": [],
#                     "endTime": "2024-08-02T08:53:17.81",
#                     "error": null,
#                     "generation": null,
#                     "id": "2abbfa91-b068-48be-b0b1-fea83a3483a6",
#                     "input": null,
#                     "metadata": {
#                         "language": null,
#                         "showInput": null,
#                         "waitForAnswer": false
#                     },
#                     "name": "cathx618@gmail.com",
#                     "output": {
#                         "content": "\ud55c\uad6d\ud615 \ub3c4\ub85c\uba85\uc8fc\uc18c\ub780 \ubb58\uae4c?"
#                     },
#                     "parentId": null,
#                     "scores": [],
#                     "startTime": "2024-08-02T08:53:17.81",
#                     "tags": null,
#                     "threadId": "46eb61fa-af7c-4a2c-9ce9-bef6f1ac7e5d",
#                     "type": "user_message"
#                 },
#                 {
#                     "attachments": [],
#                     "endTime": "2024-08-02T08:53:17.876",
#                     "error": null,
#                     "generation": null,
#                     "id": "6f0a8b3e-beb3-436a-90fc-d7d1c8f319f0",
#                     "input": {
#                         "content": "\ud55c\uad6d\ud615 \ub3c4\ub85c\uba85\uc8fc\uc18c\ub780 \ubb58\uae4c?"
#                     },
#                     "metadata": {
#                         "language": null,
#                         "showInput": "json",
#                         "waitForAnswer": null
#                     },
#                     "name": "on_message",
#                     "output": {
#                         "content": "Checkpointer requires one or more of the following 'configurable' keys: ['thread_id', 'thread_ts']"
#                     },
#                     "parentId": "2abbfa91-b068-48be-b0b1-fea83a3483a6",
#                     "scores": [],
#                     "startTime": "2024-08-02T08:53:17.813",
#                     "tags": null,
#                     "threadId": "46eb61fa-af7c-4a2c-9ce9-bef6f1ac7e5d",
#                     "type": "run"
#                 }
#             ],
#             "tags": null
#         },
#         {
#             "createdAt": "2024-08-02T08:34:52.701Z",
#             "id": "88826da4-d6af-4b4d-b537-cf4bcf8d4871",
#             "metadata": {
#                 "chat_profile": null,
#                 "chat_settings": {},
#                 "client_type": "webapp",
#                 "http_referer": "http://localhost:8000/"
#             },
#             "name": null,
#             "participant": {},
#             "steps": [
#                 {
#                     "attachments": [],
#                     "endTime": "2024-08-02T08:34:52.374",
#                     "error": null,
#                     "generation": null,
#                     "id": "d7f27532-cd53-44b9-83c1-b4ec588c306e",
#                     "input": null,
#                     "metadata": {},
#                     "name": "",
#                     "output": null,
#                     "parentId": null,
#                     "scores": [],
#                     "startTime": "2024-08-02T08:34:38.15",
#                     "tags": null,
#                     "threadId": "88826da4-d6af-4b4d-b537-cf4bcf8d4871",
#                     "type": "undefined"
#                 },
#                 {
#                     "attachments": [],
#                     "endTime": "2024-08-02T08:34:52.374",
#                     "error": null,
#                     "generation": null,
#                     "id": "50720c96-fae3-43b3-a198-e97ab1467749",
#                     "input": {
#                         "content": "\uc8fc\uc18c\ub97c \uc815\uc81c\ud558\ub294 \ubc29\ubc95\uc774 \uc788\uc744\uae4c?"
#                     },
#                     "metadata": {
#                         "language": null,
#                         "showInput": "json",
#                         "waitForAnswer": null
#                     },
#                     "name": "on_message",
#                     "output": null,
#                     "parentId": "d7f27532-cd53-44b9-83c1-b4ec588c306e",
#                     "scores": [],
#                     "startTime": "2024-08-02T08:34:38.15",
#                     "tags": null,
#                     "threadId": "88826da4-d6af-4b4d-b537-cf4bcf8d4871",
#                     "type": "run"
#                 },
#                 {
#                     "attachments": [],
#                     "endTime": "2024-08-02T08:34:52.36",
#                     "error": null,
#                     "generation": null,
#                     "id": "e9f0bd86-22ba-48ba-a651-9a4d3fa5b778",
#                     "input": null,
#                     "metadata": {
#                         "language": null,
#                         "showInput": null,
#                         "waitForAnswer": false
#                     },
#                     "name": "Assistant",
#                     "output": {
#                         "content": "\uc8fc\uc18c\ub97c \uc815\uc81c\ud558\ub294 \ubc29\ubc95\uc5d0\ub294 \uc5ec\ub7ec \uac00\uc9c0\uac00 \uc788\uc2b5\ub2c8\ub2e4. \uba3c\uc800, \uac74\ubb3c\uc758 \ubb3c\ub9ac\uc801 \uc874\uc7ac \uc720\ubb34\uc640 \uc2e4\uc81c \uc774\uc6a9 \uc5ec\ubd80\uc5d0 \ub530\ub77c \ub3c4\ub85c\uba85\uc8fc\uc18c\uc758 \uc720\ud6a8\uc131\uc744 \ud655\uc778\ud574\uc57c \ud569\ub2c8\ub2e4. \ud3d0\uc9c0\ub41c \ub3c4\ub85c\uba85\uc8fc\uc18c\uac00 \ub370\uc774\ud130\uc5d0 \ud3ec\ud568\ub418\uc5b4 \uc788\ub2e4\uba74 \ud574\ub2f9 \ub808\ucf54\ub4dc\ub97c \uc81c\uac70\ud558\uac70\ub098 \uc0c8\ub85c\uc6b4 \uc720\ud6a8 \uc8fc\uc18c\ub85c \ub300\uccb4\ud558\ub294 \uc791\uc5c5\uc774 \ud544\uc694\ud569\ub2c8\ub2e4. \uc774\ub97c \uc704\ud574 \uc678\ubd80 \uc8fc\uc18c \ub370\uc774\ud130\ubca0\uc774\uc2a4\uc640 \ub300\uc870\ud558\uc5ec \uc8fc\uc18c\uc758 \uc720\ud6a8\uc131\uc744 \uc810\uac80\ud558\ub294 \uc808\ucc28\uac00 \ud544\uc218\uc801\uc785\ub2c8\ub2e4. \n\n\ub610\ud55c, \uad6c\ubb38 \uc624\ub958\uac00 \uc788\ub294 \uc8fc\uc18c\ub97c \uc815\uc81c\ud558\uae30 \uc704\ud574 \uc815\uaddc\ud45c\ud604\uc2dd\uc744 \uc801\uc6a9\ud558\uc5ec \uc218\uc815\ud560 \uc218 \uc788\uc2b5\ub2c8\ub2e4. \uc774 \uacfc\uc815\uc740 \uc624\ub958 \ud328\ud134\ubcc4\ub85c \uc21c\ucc28\uc801\uc73c\ub85c \uc9c4\ud589\ub429\ub2c8\ub2e4. API\ub97c \ud1b5\ud574 \uc8fc\uc18c\uc758 \uc2e4\uc874 \uc5ec\ubd80\ub97c \ud655\uc778\ud558\uace0, \uac31\uc2e0\ub418\uac70\ub098 \ud3d0\uc9c0\ub41c \uc8fc\uc18c\ub97c \ud0d0\uc0c9\ud558\ub294 \uac83\ub3c4 \uc911\uc694\ud55c \ubc29\ubc95\uc785\ub2c8\ub2e4. \n\n\ucd9c\ucc98: chapter-7-3, chapter-7-4"
#                     },
#                     "parentId": "50720c96-fae3-43b3-a198-e97ab1467749",
#                     "scores": [],
#                     "startTime": "2024-08-02T08:34:52.36",
#                     "tags": null,
#                     "threadId": "88826da4-d6af-4b4d-b537-cf4bcf8d4871",
#                     "type": "assistant_message"
#                 }
#             ],
#             "tags": null
#         },
#         {
#             "createdAt": "2024-08-02T08:30:35.765Z",
#             "id": "9c1409c8-b1a7-4c1a-a8cb-ac23d1a6bb1b",
#             "metadata": {
#                 "chat_profile": null,
#                 "chat_settings": {},
#                 "client_type": "webapp",
#                 "http_referer": "http://localhost:8000/"
#             },
#             "name": "\uc0ac\ubb3c\uc8fc\uc18c\ub294 \uccb4\uacc4\uac00 \uc874\uc7ac\ud558\ub2c8?",
#             "participant": {
#                 "id": "c15ac7d2-2af7-4d92-87e9-f0d336b853fa",
#                 "identifier": "admin"
#             },
#             "steps": [
#                 {
#                     "attachments": [],
#                     "endTime": "2024-08-02T08:30:25.76",
#                     "error": null,
#                     "generation": null,
#                     "id": "dec914a9-5525-4172-b0cd-5f0a5f5ec22f",
#                     "input": null,
#                     "metadata": {
#                         "language": null,
#                         "showInput": null,
#                         "waitForAnswer": false
#                     },
#                     "name": "admin",
#                     "output": {
#                         "content": "\uc0ac\ubb3c\uc8fc\uc18c\ub294 \uccb4\uacc4\uac00 \uc874\uc7ac\ud558\ub2c8?"
#                     },
#                     "parentId": null,
#                     "scores": [],
#                     "startTime": "2024-08-02T08:30:25.76",
#                     "tags": null,
#                     "threadId": "9c1409c8-b1a7-4c1a-a8cb-ac23d1a6bb1b",
#                     "type": "user_message"
#                 },
#                 {
#                     "attachments": [],
#                     "endTime": "2024-08-02T08:30:35.386",
#                     "error": null,
#                     "generation": null,
#                     "id": "3f200e8b-50a3-439e-9ced-9fc7ee5f4623",
#                     "input": {
#                         "content": "\uc0ac\ubb3c\uc8fc\uc18c\ub294 \uccb4\uacc4\uac00 \uc874\uc7ac\ud558\ub2c8?"
#                     },
#                     "metadata": {
#                         "language": null,
#                         "showInput": "json",
#                         "waitForAnswer": null
#                     },
#                     "name": "on_message",
#                     "output": null,
#                     "parentId": "dec914a9-5525-4172-b0cd-5f0a5f5ec22f",
#                     "scores": [],
#                     "startTime": "2024-08-02T08:30:25.763",
#                     "tags": null,
#                     "threadId": "9c1409c8-b1a7-4c1a-a8cb-ac23d1a6bb1b",
#                     "type": "run"
#                 },
#                 {
#                     "attachments": [],
#                     "endTime": "2024-08-02T08:30:35.373",
#                     "error": null,
#                     "generation": null,
#                     "id": "b707dcf6-9709-4d85-8f28-f123cb6178f7",
#                     "input": null,
#                     "metadata": {
#                         "language": null,
#                         "showInput": null,
#                         "waitForAnswer": false
#                     },
#                     "name": "Assistant",
#                     "output": {
#                         "content": "\uc0ac\ubb3c\uc8fc\uc18c\ub294 \uccb4\uacc4\uac00 \uc874\uc7ac\ud569\ub2c8\ub2e4. \uc0ac\ubb3c\uc8fc\uc18c\ub294 \ub3c4\ub85c\uba85\uc8fc\uc18c\ubc95 \ub4f1 \uad00\ub828 \ubc95\ub839\uc744 \ubc14\ud0d5\uc73c\ub85c \ub370\uc774\ud130 \uad00\uc810\uc5d0\uc11c \uccb4\uacc4\uac00 \ubd84\uc11d\ub418\uace0 \uc788\uc73c\uba70, \uc8fc\uc18c \uad6c\uc131\uc694\uc18c\uc640 \uc8fc\uc18c \ubd80\uc5ec \ub300\uc0c1 \ub4f1 \ub2e4\uc591\ud55c \uc694\uc18c\uc640 \uc5f0\uad00\ub418\uc5b4 \uc788\uc2b5\ub2c8\ub2e4. [\ucd9c\ucc98: \uae40\uc9c0\uc601-\uc0ac\ubb3c\uc8fc\uc18c \ubd80\uc5ec \uccb4\uacc4 \ubd84\uc11d \ubc0f \uc815\ucc45\uc81c\uc5b8-2023]"
#                     },
#                     "parentId": "3f200e8b-50a3-439e-9ced-9fc7ee5f4623",
#                     "scores": [],
#                     "startTime": "2024-08-02T08:30:35.373",
#                     "tags": null,
#                     "threadId": "9c1409c8-b1a7-4c1a-a8cb-ac23d1a6bb1b",
#                     "type": "assistant_message"
#                 }
#             ],
#             "tags": null
#         },
#         {
#             "createdAt": "2024-08-02T08:28:57.969Z",
#             "id": "e0da7bdd-8ba7-4098-ac84-1f0f55440b92",
#             "metadata": {
#                 "chat_profile": null,
#                 "chat_settings": {},
#                 "client_type": "webapp",
#                 "http_referer": "http://localhost:8000/"
#             },
#             "name": "hi",
#             "participant": {
#                 "id": "c15ac7d2-2af7-4d92-87e9-f0d336b853fa",
#                 "identifier": "admin"
#             },
#             "steps": [
#                 {
#                     "attachments": [],
#                     "endTime": "2024-08-02T08:28:53.042",
#                     "error": null,
#                     "generation": null,
#                     "id": "9f8036d0-317c-4480-9929-863769c34220",
#                     "input": null,
#                     "metadata": {
#                         "language": null,
#                         "showInput": null,
#                         "waitForAnswer": false
#                     },
#                     "name": "admin",
#                     "output": {
#                         "content": "hi"
#                     },
#                     "parentId": null,
#                     "scores": [],
#                     "startTime": "2024-08-02T08:28:53.042",
#                     "tags": null,
#                     "threadId": "e0da7bdd-8ba7-4098-ac84-1f0f55440b92",
#                     "type": "user_message"
#                 },
#                 {
#                     "attachments": [],
#                     "endTime": "2024-08-02T08:28:57.66",
#                     "error": null,
#                     "generation": null,
#                     "id": "b10959c8-e97c-49e3-9f4a-4083b512801a",
#                     "input": {
#                         "content": "hi"
#                     },
#                     "metadata": {
#                         "language": null,
#                         "showInput": "json",
#                         "waitForAnswer": null
#                     },
#                     "name": "on_message",
#                     "output": null,
#                     "parentId": "9f8036d0-317c-4480-9929-863769c34220",
#                     "scores": [],
#                     "startTime": "2024-08-02T08:28:53.045",
#                     "tags": null,
#                     "threadId": "e0da7bdd-8ba7-4098-ac84-1f0f55440b92",
#                     "type": "run"
#                 },
#                 {
#                     "attachments": [],
#                     "endTime": "2024-08-02T08:28:57.646",
#                     "error": null,
#                     "generation": null,
#                     "id": "7e067f25-78ca-4343-8328-c4d7435b3a50",
#                     "input": null,
#                     "metadata": {
#                         "language": null,
#                         "showInput": null,
#                         "waitForAnswer": false
#                     },
#                     "name": "Assistant",
#                     "output": {
#                         "content": "\uc548\ub155\ud558\uc138\uc694! \ubb34\uc5c7\uc744 \ub3c4\uc640\ub4dc\ub9b4\uae4c\uc694?"
#                     },
#                     "parentId": "b10959c8-e97c-49e3-9f4a-4083b512801a",
#                     "scores": [],
#                     "startTime": "2024-08-02T08:28:57.646",
#                     "tags": null,
#                     "threadId": "e0da7bdd-8ba7-4098-ac84-1f0f55440b92",
#                     "type": "assistant_message"
#                 },
#                 {
#                     "attachments": [],
#                     "endTime": "2024-08-02T08:29:19.593",
#                     "error": null,
#                     "generation": null,
#                     "id": "89dc2329-1383-494f-8764-8d41c0a322f3",
#                     "input": null,
#                     "metadata": {
#                         "language": null,
#                         "showInput": null,
#                         "waitForAnswer": false
#                     },
#                     "name": "admin",
#                     "output": {
#                         "content": "\ud504\ub791\uc2a4\uc5b4\ub85c \uc548\ub155\uc740 \ubb50\uc57c?"
#                     },
#                     "parentId": null,
#                     "scores": [],
#                     "startTime": "2024-08-02T08:29:19.593",
#                     "tags": null,
#                     "threadId": "e0da7bdd-8ba7-4098-ac84-1f0f55440b92",
#                     "type": "user_message"
#                 },
#                 {
#                     "attachments": [],
#                     "endTime": "2024-08-02T08:29:24.974",
#                     "error": null,
#                     "generation": null,
#                     "id": "d4ea9d80-d075-437f-ad45-c62f1c978e07",
#                     "input": {
#                         "content": "\ud504\ub791\uc2a4\uc5b4\ub85c \uc548\ub155\uc740 \ubb50\uc57c?"
#                     },
#                     "metadata": {
#                         "language": null,
#                         "showInput": "json",
#                         "waitForAnswer": null
#                     },
#                     "name": "on_message",
#                     "output": null,
#                     "parentId": "89dc2329-1383-494f-8764-8d41c0a322f3",
#                     "scores": [],
#                     "startTime": "2024-08-02T08:29:19.597",
#                     "tags": null,
#                     "threadId": "e0da7bdd-8ba7-4098-ac84-1f0f55440b92",
#                     "type": "run"
#                 },
#                 {
#                     "attachments": [],
#                     "endTime": "2024-08-02T08:29:24.961",
#                     "error": null,
#                     "generation": null,
#                     "id": "1f7af33d-ea21-48fa-bbb6-ee036e1e5a9a",
#                     "input": null,
#                     "metadata": {
#                         "language": null,
#                         "showInput": null,
#                         "waitForAnswer": false
#                     },
#                     "name": "Assistant",
#                     "output": {
#                         "content": "\ud504\ub791\uc2a4\uc5b4\ub85c \"\uc548\ub155\"\uc740 \"Bonjour\"\uc785\ub2c8\ub2e4. \"Bonjour\"\ub294 \uc8fc\ub85c \uc544\uce68\ubd80\ud130 \uc624\ud6c4\uae4c\uc9c0 \uc0ac\uc6a9\ub418\uba70, \uc800\ub141 \uc778\uc0ac\ub85c\ub294 \"Bonsoir\"\ub97c \uc0ac\uc6a9\ud569\ub2c8\ub2e4."
#                     },
#                     "parentId": "d4ea9d80-d075-437f-ad45-c62f1c978e07",
#                     "scores": [],
#                     "startTime": "2024-08-02T08:29:24.961",
#                     "tags": null,
#                     "threadId": "e0da7bdd-8ba7-4098-ac84-1f0f55440b92",
#                     "type": "assistant_message"
#                 }
#             ],
#             "tags": null
#         },
#         {
#             "createdAt": "2024-08-02T08:27:08.060Z",
#             "id": "eab1723c-0463-4a42-8d63-9004d67e8437",
#             "metadata": {
#                 "chat_profile": null,
#                 "chat_settings": {},
#                 "client_type": "webapp",
#                 "http_referer": "http://localhost:8000/"
#             },
#             "name": null,
#             "participant": {},
#             "steps": [
#                 {
#                     "attachments": [],
#                     "endTime": "2024-08-02T08:27:07.661",
#                     "error": null,
#                     "generation": null,
#                     "id": "16b9330a-8f0e-42f1-a865-82c9154cd222",
#                     "input": null,
#                     "metadata": {},
#                     "name": "",
#                     "output": null,
#                     "parentId": null,
#                     "scores": [],
#                     "startTime": "2024-08-02T08:26:55.102",
#                     "tags": null,
#                     "threadId": "eab1723c-0463-4a42-8d63-9004d67e8437",
#                     "type": "undefined"
#                 },
#                 {
#                     "attachments": [],
#                     "endTime": "2024-08-02T08:27:07.661",
#                     "error": null,
#                     "generation": null,
#                     "id": "e172b013-bc71-4c29-89c2-a20248574d3e",
#                     "input": {
#                         "content": "\ub300\ud55c\ubbfc\uad6d\uc758 \ub3c4\ub85c\uba85\uc8fc\uc18c\ub294 \uc5b4\ub290 \uae30\uad00\uc5d0\uc11c \uad00\ub9ac\ud574?"
#                     },
#                     "metadata": {
#                         "language": null,
#                         "showInput": "json",
#                         "waitForAnswer": null
#                     },
#                     "name": "on_message",
#                     "output": null,
#                     "parentId": "16b9330a-8f0e-42f1-a865-82c9154cd222",
#                     "scores": [],
#                     "startTime": "2024-08-02T08:26:55.102",
#                     "tags": null,
#                     "threadId": "eab1723c-0463-4a42-8d63-9004d67e8437",
#                     "type": "run"
#                 },
#                 {
#                     "attachments": [],
#                     "endTime": "2024-08-02T08:27:07.644",
#                     "error": null,
#                     "generation": null,
#                     "id": "da937b92-7c98-454a-afe4-2a7c182ba508",
#                     "input": null,
#                     "metadata": {
#                         "language": null,
#                         "showInput": null,
#                         "waitForAnswer": false
#                     },
#                     "name": "Assistant",
#                     "output": {
#                         "content": "\ub300\ud55c\ubbfc\uad6d\uc758 \ub3c4\ub85c\uba85\uc8fc\uc18c\ub294 \ud589\uc815\uc548\uc804\ubd80\uc5d0\uc11c \uad00\ub9ac\ud569\ub2c8\ub2e4. [\ucd9c\ucc98: namu.wiki/w/\ub3c4\ub85c\uba85\uc8fc\uc18c]"
#                     },
#                     "parentId": "e172b013-bc71-4c29-89c2-a20248574d3e",
#                     "scores": [],
#                     "startTime": "2024-08-02T08:27:07.644",
#                     "tags": null,
#                     "threadId": "eab1723c-0463-4a42-8d63-9004d67e8437",
#                     "type": "assistant_message"
#                 }
#             ],
#             "tags": null
#         },
#         {
#             "createdAt": "2024-08-02T08:25:54.800Z",
#             "id": "2122f090-2df2-43cc-a99f-f5f027b7d098",
#             "metadata": {
#                 "chat_profile": null,
#                 "chat_settings": {},
#                 "client_type": "webapp",
#                 "http_referer": "http://localhost:8000/thread/8abfeb11-8623-45bb-86f1-1ec023ca3e35"
#             },
#             "name": "\uc8fc\uc18c\ub97c \uc2dd\ubcc4\ud560 \uc218 \uc788\ub294 \uc2dd\ubcc4\uc790\uc758 \uc885\ub958\ub97c \uc54c\ub824\uc918",
#             "participant": {
#                 "id": "e03188a4-7c06-4da4-b26f-4cade142a733",
#                 "identifier": "jeongyun.2ee@gmail.com"
#             },
#             "steps": [
#                 {
#                     "attachments": [],
#                     "endTime": "2024-08-02T08:25:47.243",
#                     "error": null,
#                     "generation": null,
#                     "id": "7cd821e3-1ffe-4682-9f0a-ab0cea73cfbb",
#                     "input": null,
#                     "metadata": {
#                         "language": null,
#                         "showInput": null,
#                         "waitForAnswer": false
#                     },
#                     "name": "jeongyun.2ee@gmail.com",
#                     "output": {
#                         "content": "\uc8fc\uc18c\ub97c \uc2dd\ubcc4\ud560 \uc218 \uc788\ub294 \uc2dd\ubcc4\uc790\uc758 \uc885\ub958\ub97c \uc54c\ub824\uc918"
#                     },
#                     "parentId": null,
#                     "scores": [],
#                     "startTime": "2024-08-02T08:25:47.243",
#                     "tags": null,
#                     "threadId": "2122f090-2df2-43cc-a99f-f5f027b7d098",
#                     "type": "user_message"
#                 },
#                 {
#                     "attachments": [],
#                     "endTime": "2024-08-02T08:25:54.379",
#                     "error": null,
#                     "generation": null,
#                     "id": "a83797d8-12e5-447f-b34e-5865815b32ca",
#                     "input": {
#                         "content": "\uc8fc\uc18c\ub97c \uc2dd\ubcc4\ud560 \uc218 \uc788\ub294 \uc2dd\ubcc4\uc790\uc758 \uc885\ub958\ub97c \uc54c\ub824\uc918"
#                     },
#                     "metadata": {
#                         "language": null,
#                         "showInput": "json",
#                         "waitForAnswer": null
#                     },
#                     "name": "on_message",
#                     "output": null,
#                     "parentId": "7cd821e3-1ffe-4682-9f0a-ab0cea73cfbb",
#                     "scores": [],
#                     "startTime": "2024-08-02T08:25:47.246",
#                     "tags": null,
#                     "threadId": "2122f090-2df2-43cc-a99f-f5f027b7d098",
#                     "type": "run"
#                 },
#                 {
#                     "attachments": [],
#                     "endTime": "2024-08-02T08:25:54.366",
#                     "error": null,
#                     "generation": null,
#                     "id": "1d91c5fd-07fa-4b95-9f6b-f9398431db33",
#                     "input": null,
#                     "metadata": {
#                         "language": null,
#                         "showInput": null,
#                         "waitForAnswer": false
#                     },
#                     "name": "Assistant",
#                     "output": {
#                         "content": "\uc8fc\uc18c\ub97c \uc2dd\ubcc4\ud560 \uc218 \uc788\ub294 \uc2dd\ubcc4\uc790\uc758 \uc885\ub958\ub85c\ub294 \uc8fc\uc18c\uc815\ubcf4\uc758 \uc720\uc77c\uc131\uc744 \ud655\uc778\ud558\ub294 \uc808\ucc28\ub098 \uc8fc\uc18c\uc815\ubcf4\uc758 \uc2dd\ubcc4 \ubd80\ud638(ID)\uac00 \uc788\uc2b5\ub2c8\ub2e4. \uc774\ub294 \uc8fc\uc18c\uc815\ubcf4\uc758 \uc99d\uba85 \ubc0f \ud655\uc778\uc744 \uc704\ud55c \uc785\ub825\uac12\uc73c\ub85c \uc0ac\uc6a9\ub429\ub2c8\ub2e4 (\ucd9c\ucc98: \uc8fc\uc18c\uc6a9\uc5b4\ucd5c\uc885\uc815\ub9ac_1123 - \uc5c5\ub370\uc774\ud2b8_231123)."
#                     },
#                     "parentId": "a83797d8-12e5-447f-b34e-5865815b32ca",
#                     "scores": [],
#                     "startTime": "2024-08-02T08:25:54.366",
#                     "tags": null,
#                     "threadId": "2122f090-2df2-43cc-a99f-f5f027b7d098",
#                     "type": "assistant_message"
#                 }
#             ],
#             "tags": null
#         },
#         {
#             "createdAt": "2024-08-02T08:23:11.352Z",
#             "id": "8abfeb11-8623-45bb-86f1-1ec023ca3e35",
#             "metadata": {
#                 "chat_profile": null,
#                 "chat_settings": {},
#                 "client_type": "webapp",
#                 "http_referer": "http://localhost:8000/thread/75d4c0e9-c96b-4459-a634-f9c2bc362232"
#             },
#             "name": "\uc8fc\uc18c\uc815\ubcf4\uc758 \uac1c\ub150\uc740?",
#             "participant": {
#                 "id": "e03188a4-7c06-4da4-b26f-4cade142a733",
#                 "identifier": "jeongyun.2ee@gmail.com"
#             },
#             "steps": [
#                 {
#                     "attachments": [],
#                     "endTime": "2024-08-02T08:23:01.351",
#                     "error": null,
#                     "generation": null,
#                     "id": "a71b602d-ad50-4484-aa84-58a4c1503c4a",
#                     "input": null,
#                     "metadata": {
#                         "language": null,
#                         "showInput": null,
#                         "waitForAnswer": false
#                     },
#                     "name": "jeongyun.2ee@gmail.com",
#                     "output": {
#                         "content": "\uc8fc\uc18c\uc815\ubcf4\uc758 \uac1c\ub150\uc740?"
#                     },
#                     "parentId": null,
#                     "scores": [],
#                     "startTime": "2024-08-02T08:23:01.351",
#                     "tags": null,
#                     "threadId": "8abfeb11-8623-45bb-86f1-1ec023ca3e35",
#                     "type": "user_message"
#                 },
#                 {
#                     "attachments": [],
#                     "endTime": "2024-08-02T08:23:11.062",
#                     "error": null,
#                     "generation": null,
#                     "id": "d3a5d74f-04db-4b29-b11a-12000a37411a",
#                     "input": {
#                         "content": "\uc8fc\uc18c\uc815\ubcf4\uc758 \uac1c\ub150\uc740?"
#                     },
#                     "metadata": {
#                         "language": null,
#                         "showInput": "json",
#                         "waitForAnswer": null
#                     },
#                     "name": "on_message",
#                     "output": null,
#                     "parentId": "a71b602d-ad50-4484-aa84-58a4c1503c4a",
#                     "scores": [],
#                     "startTime": "2024-08-02T08:23:01.354",
#                     "tags": null,
#                     "threadId": "8abfeb11-8623-45bb-86f1-1ec023ca3e35",
#                     "type": "run"
#                 },
#                 {
#                     "attachments": [],
#                     "endTime": "2024-08-02T08:23:11.049",
#                     "error": null,
#                     "generation": null,
#                     "id": "53d2de5f-8deb-4f84-8760-9261f260ef78",
#                     "input": null,
#                     "metadata": {
#                         "language": null,
#                         "showInput": null,
#                         "waitForAnswer": false
#                     },
#                     "name": "Assistant",
#                     "output": {
#                         "content": "\uc8fc\uc18c\uc815\ubcf4\ub294 \uc2dd\ubcc4\uacfc \uc704\uce58 \ud30c\uc545\uc744 \ubaa9\uc801\uc73c\ub85c \uac1d\uccb4\ub97c \uba85\ud655\ud558\uac8c \ud655\uc778\ud560 \uc218 \uc788\uac8c \ud558\ub294 \uad6c\uc870\ud654\ub41c \uc815\ubcf4\ub97c \ub9d0\ud569\ub2c8\ub2e4. \uc5ec\uae30\uc5d0\ub294 \ub3c4\ud615\uc815\ubcf4\uc640 \uc18d\uc131\uc815\ubcf4 \ubaa8\ub450\ub97c \ud3ec\ud568\ud569\ub2c8\ub2e4. \ub610\ud55c, \ub3c4\ub85c\uba85\uc8fc\uc18c\ubc95\uc5d0\uc11c\ub294 \uc8fc\uc18c\uc815\ubcf4\ub97c \uac74\ubb3c\uc744 \ud45c\uc2dc\ud558\ub294 \ub3c4\ub85c\uba85\uc8fc\uc18c, \uc2dc\uc124\ubb3c\uc744 \ud45c\uc2dc\ud558\ub294 \uc0ac\ubb3c\uc8fc\uc18c, \uacf5\ud130\ub97c \ud45c\uc2dc\ud558\ub294 \uae30\ucd08\ubc88\ud638\uc640 \uad6d\uac00\uc9c0\uc810\ubc88\ud638, \uad6c\uc5ed\uc744 \ud45c\uc2dc\ud558\ub294 \uad6d\uac00\uae30\ucd08\uad6c\uc5ed\uc73c\ub85c \ubd84\ub958\ud558\uace0 \uc774\uc5d0 \uad00\ud55c \uc815\ubcf4\ub97c \ud3ec\ud568\ud558\uc5ec \uc815\uc758\ud558\uace0 \uc788\uc2b5\ub2c8\ub2e4. (data/final)"
#                     },
#                     "parentId": "d3a5d74f-04db-4b29-b11a-12000a37411a",
#                     "scores": [],
#                     "startTime": "2024-08-02T08:23:11.049",
#                     "tags": null,
#                     "threadId": "8abfeb11-8623-45bb-86f1-1ec023ca3e35",
#                     "type": "assistant_message"
#                 }
#             ],
#             "tags": null
#         },
#         {
#             "createdAt": "2024-08-02T08:21:46.884Z",
#             "id": "75d4c0e9-c96b-4459-a634-f9c2bc362232",
#             "metadata": {
#                 "chat_profile": null,
#                 "chat_settings": {},
#                 "client_type": "webapp",
#                 "http_referer": "http://localhost:8000/"
#             },
#             "name": "hi",
#             "participant": {
#                 "id": "e03188a4-7c06-4da4-b26f-4cade142a733",
#                 "identifier": "jeongyun.2ee@gmail.com"
#             },
#             "steps": [
#                 {
#                     "attachments": [],
#                     "endTime": "2024-08-02T08:21:41.538",
#                     "error": null,
#                     "generation": null,
#                     "id": "013a9994-b931-43c9-bbb0-b9116002dc74",
#                     "input": null,
#                     "metadata": {
#                         "language": null,
#                         "showInput": null,
#                         "waitForAnswer": false
#                     },
#                     "name": "jeongyun.2ee@gmail.com",
#                     "output": {
#                         "content": "hi"
#                     },
#                     "parentId": null,
#                     "scores": [],
#                     "startTime": "2024-08-02T08:21:41.538",
#                     "tags": null,
#                     "threadId": "75d4c0e9-c96b-4459-a634-f9c2bc362232",
#                     "type": "user_message"
#                 },
#                 {
#                     "attachments": [],
#                     "endTime": "2024-08-02T08:21:46.569",
#                     "error": null,
#                     "generation": null,
#                     "id": "d3677582-f688-45e0-b47d-09a005ac83fa",
#                     "input": {
#                         "content": "hi"
#                     },
#                     "metadata": {
#                         "language": null,
#                         "showInput": "json",
#                         "waitForAnswer": null
#                     },
#                     "name": "on_message",
#                     "output": null,
#                     "parentId": "013a9994-b931-43c9-bbb0-b9116002dc74",
#                     "scores": [],
#                     "startTime": "2024-08-02T08:21:41.541",
#                     "tags": null,
#                     "threadId": "75d4c0e9-c96b-4459-a634-f9c2bc362232",
#                     "type": "run"
#                 },
#                 {
#                     "attachments": [],
#                     "endTime": "2024-08-02T08:21:46.556",
#                     "error": null,
#                     "generation": null,
#                     "id": "299d4a58-823b-4344-bc1d-0d15a3e02a23",
#                     "input": null,
#                     "metadata": {
#                         "language": null,
#                         "showInput": null,
#                         "waitForAnswer": false
#                     },
#                     "name": "Assistant",
#                     "output": {
#                         "content": "\uc548\ub155\ud558\uc138\uc694! \ubb34\uc5c7\uc744 \ub3c4\uc640\ub4dc\ub9b4\uae4c\uc694? \uc77c\ubc18\uc801\uc778 \uc9c8\ubb38\uc774\ub098 \uc815\ubcf4\uc5d0 \ub300\ud574 \ub2f5\ubcc0\ud574\ub4dc\ub9b4 \uc218 \uc788\uc2b5\ub2c8\ub2e4."
#                     },
#                     "parentId": "d3677582-f688-45e0-b47d-09a005ac83fa",
#                     "scores": [],
#                     "startTime": "2024-08-02T08:21:46.556",
#                     "tags": null,
#                     "threadId": "75d4c0e9-c96b-4459-a634-f9c2bc362232",
#                     "type": "assistant_message"
#                 }
#             ],
#             "tags": null
#         },
#         {
#             "createdAt": "2024-08-02T08:16:25.831Z",
#             "id": "f0a95954-2388-411e-b78c-28e409cd795a",
#             "metadata": {
#                 "chat_profile": null,
#                 "chat_settings": {},
#                 "client_type": "webapp",
#                 "http_referer": "http://localhost:8000/"
#             },
#             "name": null,
#             "participant": {},
#             "steps": [
#                 {
#                     "attachments": [],
#                     "endTime": "2024-08-02T08:16:25.21",
#                     "error": null,
#                     "generation": null,
#                     "id": "cfa6400d-8b4f-4c83-8f55-86d125797224",
#                     "input": {
#                         "content": "\ub3c4\ub85c\uba85\uc8fc\uc18c\uc640 \uc9c0\ubc88\uc8fc\uc18c\uc758 \ucc28\uc774\uac00 \ubb50\uc57c?"
#                     },
#                     "metadata": {
#                         "language": null,
#                         "showInput": "json",
#                         "waitForAnswer": null
#                     },
#                     "name": "on_message",
#                     "output": null,
#                     "parentId": "35637f18-ca6f-42d2-83bf-ec59cc14b468",
#                     "scores": [],
#                     "startTime": "2024-08-02T08:16:11.884",
#                     "tags": null,
#                     "threadId": "f0a95954-2388-411e-b78c-28e409cd795a",
#                     "type": "run"
#                 },
#                 {
#                     "attachments": [],
#                     "endTime": "2024-08-02T08:16:25.21",
#                     "error": null,
#                     "generation": null,
#                     "id": "35637f18-ca6f-42d2-83bf-ec59cc14b468",
#                     "input": null,
#                     "metadata": {},
#                     "name": "",
#                     "output": null,
#                     "parentId": null,
#                     "scores": [],
#                     "startTime": "2024-08-02T08:16:11.884",
#                     "tags": null,
#                     "threadId": "f0a95954-2388-411e-b78c-28e409cd795a",
#                     "type": "undefined"
#                 },
#                 {
#                     "attachments": [],
#                     "endTime": "2024-08-02T08:16:25.195",
#                     "error": null,
#                     "generation": null,
#                     "id": "22b92ccd-4de0-4333-accf-ad7dda758c8b",
#                     "input": null,
#                     "metadata": {
#                         "language": null,
#                         "showInput": null,
#                         "waitForAnswer": false
#                     },
#                     "name": "Assistant",
#                     "output": {
# ...
#                 "chat_settings": {},
#                 "client_type": "webapp",
#                 "http_referer": "http://localhost:8000/"
#             },
#             "name": "hi",
#             "participant": {
#                 "id": "d2ad291c-0975-45d4-9407-77930d045ca7",
#                 "identifier": "cathx618@gmail.com"
#             },
#             "steps": [
#                 {
#                     "attachments": [],
#                     "endTime": "2024-08-02T07:52:55.854",
#                     "error": null,
#                     "generation": null,
#                     "id": "eaadb16d-1e44-43c7-868a-8104805da602",
#                     "input": null,
#                     "metadata": {
#                         "language": null,
#                         "showInput": null,
#                         "waitForAnswer": false
#                     },
#                     "name": "cathx618@gmail.com",
#                     "output": {
#                         "content": "hi"
#                     },
#                     "parentId": null,
#                     "scores": [],
#                     "startTime": "2024-08-02T07:52:55.854",
#                     "tags": null,
#                     "threadId": "50e1f4ef-52af-4fc4-817c-1e143d9fb1a4",
#                     "type": "user_message"
#                 },
#                 {
#                     "attachments": [],
#                     "endTime": "2024-08-02T07:53:01.491",
#                     "error": null,
#                     "generation": null,
#                     "id": "0457a1dc-dd56-4d4d-ba54-e8e762dfec69",
#                     "input": {
#                         "content": "hi"
#                     },
#                     "metadata": {
#                         "language": null,
#                         "showInput": "json",
#                         "waitForAnswer": null
#                     },
#                     "name": "on_message",
#                     "output": null,
#                     "parentId": "eaadb16d-1e44-43c7-868a-8104805da602",
#                     "scores": [],
#                     "startTime": "2024-08-02T07:52:55.858",
#                     "tags": null,
#                     "threadId": "50e1f4ef-52af-4fc4-817c-1e143d9fb1a4",
#                     "type": "run"
#                 },
#                 {
#                     "attachments": [],
#                     "endTime": "2024-08-02T07:53:01.477",
#                     "error": null,
#                     "generation": null,
#                     "id": "392f8087-6fb0-4f98-99e1-f57ca7dab912",
#                     "input": null,
#                     "metadata": {
#                         "language": null,
#                         "showInput": null,
#                         "waitForAnswer": false
#                     },
#                     "name": "Assistant",
#                     "output": {
#                         "content": "\uc548\ub155\ud558\uc138\uc694! \ubb34\uc5c7\uc744 \ub3c4\uc640\ub4dc\ub9b4\uae4c\uc694? \uc77c\ubc18\uc801\uc778 \uc0c1\uc2dd\uc774\ub098 \uc815\ubcf4\uc5d0 \ub300\ud574 \uad81\uae08\ud55c \uc810\uc774 \uc788\uc73c\uc2dc\uba74 \ub9d0\uc500\ud574 \uc8fc\uc138\uc694."
#                     },
#                     "parentId": "0457a1dc-dd56-4d4d-ba54-e8e762dfec69",
#                     "scores": [],
#                     "startTime": "2024-08-02T07:53:01.477",
#                     "tags": null,
#                     "threadId": "50e1f4ef-52af-4fc4-817c-1e143d9fb1a4",
#                     "type": "assistant_message"
#                 }
#             ],
#             "tags": null
#         },
#         {
#             "createdAt": "2024-08-02T07:50:56.264Z",
#             "id": "cf94a044-b36f-4d3a-9894-6dcfc8e7a75c",
#             "metadata": {
#                 "chat_profile": null,
#                 "chat_settings": {},
#                 "client_type": "webapp",
#                 "http_referer": "http://localhost:8000/"
#             },
#             "name": null,
#             "participant": {},
#             "steps": [
#                 {
#                     "attachments": [],
#                     "endTime": "2024-08-02T07:50:55.935",
#                     "error": null,
#                     "generation": null,
#                     "id": "9f997b6d-314b-4977-86cc-8df3b1cac7aa",
#                     "input": {
#                         "content": "\uac74\ucd95\ubb3c\ub300\uc7a5\uc5d0 \ub300\ud574\uc11c \uc54c\ub824\uc918"
#                     },
#                     "metadata": {
#                         "language": null,
#                         "showInput": "json",
#                         "waitForAnswer": null
#                     },
#                     "name": "on_message",
#                     "output": null,
#                     "parentId": "fedf26d5-9b2b-4aae-b7e1-e7e01a0428da",
#                     "scores": [],
#                     "startTime": "2024-08-02T07:50:41.946",
#                     "tags": null,
#                     "threadId": "cf94a044-b36f-4d3a-9894-6dcfc8e7a75c",
#                     "type": "run"
#                 },
#                 {
#                     "attachments": [],
#                     "endTime": "2024-08-02T07:50:55.935",
#                     "error": null,
#                     "generation": null,
#                     "id": "fedf26d5-9b2b-4aae-b7e1-e7e01a0428da",
#                     "input": null,
#                     "metadata": {},
#                     "name": "",
#                     "output": null,
#                     "parentId": null,
#                     "scores": [],
#                     "startTime": "2024-08-02T07:50:41.946",
#                     "tags": null,
#                     "threadId": "cf94a044-b36f-4d3a-9894-6dcfc8e7a75c",
#                     "type": "undefined"
#                 },
#                 {
#                     "attachments": [],
#                     "endTime": "2024-08-02T07:50:55.922",
#                     "error": null,
#                     "generation": null,
#                     "id": "9d114198-096f-4c14-99f0-4543dc3fcbea",
#                     "input": null,
#                     "metadata": {
#                         "language": null,
#                         "showInput": null,
#                         "waitForAnswer": false
#                     },
#                     "name": "Assistant",
#                     "output": {
#                         "content": "\uac74\ucd95\ubb3c\ub300\uc7a5\uc740 \uac01 \uac74\ubb3c\uc5d0 \ub300\ud55c \uc815\ubcf4\ub97c \uc815\ub9ac\ud55c \uad6d\uac00 \uae30\uad00\uc758 \uacf5\uc2dd \ubb38\uc11c\uc785\ub2c8\ub2e4. \uc774 \ubb38\uc11c\uc5d0\ub294 \uac74\ucd95\ubb3c\uc758 \uc704\uce58, \uba74\uc801, \uad6c\uc870, \uc6a9\ub3c4, \uce35\uc218, \uc0ac\uc6a9\uc2b9\uc778\uc77c \ub4f1\uc758 \uac74\ucd95\ubb3c \ud45c\uc2dc\uc5d0 \uad00\ud55c \uc0ac\ud56d\uacfc \uc18c\uc720\uc790 \uc131\uba85, \uc8fc\uc18c, \uc18c\uc720\uad8c \uc9c0\ubd84 \ub4f1\uc758 \uc18c\uc720\uc790 \ud604\ud669\uc5d0 \uad00\ud55c \uc0ac\ud56d\uc774 \ub4f1\ub85d\ub418\uc5b4 \uc788\uc2b5\ub2c8\ub2e4. \ubd80\ub3d9\uc0b0 \uac70\ub798\ub098 \ubd84\uc11d, \ub9ac\ubaa8\ub378\ub9c1 \uacc4\ud68d \uc2dc \uc911\uc694\ud55c \ucc38\uace0 \uc790\ub8cc\ub85c \uc0ac\uc6a9\ub429\ub2c8\ub2e4. [\ucd9c\ucc98: circle2.tistory.com]"
#                     },
#                     "parentId": "9f997b6d-314b-4977-86cc-8df3b1cac7aa",
#                     "scores": [],
#                     "startTime": "2024-08-02T07:50:55.922",
#                     "tags": null,
#                     "threadId": "cf94a044-b36f-4d3a-9894-6dcfc8e7a75c",
#                     "type": "assistant_message"
#                 }
#             ],
#             "tags": null
#         },
#         {
#             "createdAt": "2024-08-02T07:48:32.436Z",
#             "id": "1f800824-8c2f-4d1f-86fb-0bcbc580577f",
#             "metadata": {
#                 "chat_profile": null,
#                 "chat_settings": {},
#                 "client_type": "webapp",
#                 "http_referer": "http://localhost:8000/"
#             },
#             "name": null,
#             "participant": {},
#             "steps": [
#                 {
#                     "attachments": [],
#                     "endTime": "2024-08-02T07:48:31.984",
#                     "error": null,
#                     "generation": null,
#                     "id": "92e79c44-eb3d-4f64-9424-ecb3f0400d2a",
#                     "input": null,
#                     "metadata": {},
#                     "name": "",
#                     "output": null,
#                     "parentId": null,
#                     "scores": [],
#                     "startTime": "2024-08-02T07:48:10.864",
#                     "tags": null,
#                     "threadId": "1f800824-8c2f-4d1f-86fb-0bcbc580577f",
#                     "type": "undefined"
#                 },
#                 {
#                     "attachments": [],
#                     "endTime": "2024-08-02T07:48:31.984",
#                     "error": null,
#                     "generation": null,
#                     "id": "0b2b74b2-6973-4791-b83a-f7bb8e4d281e",
#                     "input": {
#                         "content": "\uac74\ucd95\ubb3c\ub300\uc7a5\uc5d0 \ub300\ud574\uc11c \uc54c\ub824\uc918"
#                     },
#                     "metadata": {
#                         "language": null,
#                         "showInput": "json",
#                         "waitForAnswer": null
#                     },
#                     "name": "on_message",
#                     "output": null,
#                     "parentId": "92e79c44-eb3d-4f64-9424-ecb3f0400d2a",
#                     "scores": [],
#                     "startTime": "2024-08-02T07:48:10.864",
#                     "tags": null,
#                     "threadId": "1f800824-8c2f-4d1f-86fb-0bcbc580577f",
#                     "type": "run"
#                 },
#                 {
#                     "attachments": [],
#                     "endTime": "2024-08-02T07:48:31.969",
#                     "error": null,
#                     "generation": null,
#                     "id": "570538ba-85c4-4d48-9390-2db27fe63620",
#                     "input": null,
#                     "metadata": {
#                         "language": null,
#                         "showInput": null,
#                         "waitForAnswer": false
#                     },
#                     "name": "Assistant",
#                     "output": {
#                         "content": "\uac74\ucd95\ubb3c\ub300\uc7a5\uc740 \uac01 \uac74\ubb3c\uc5d0 \ub300\ud55c \uc815\ubcf4\ub97c \uc815\ub9ac\ud55c \uad6d\uac00 \uae30\uad00\uc758 \uacf5\uc2dd \ubb38\uc11c\uc785\ub2c8\ub2e4. \uc774 \ubb38\uc11c\uc5d0\ub294 \uac74\ucd95\ubb3c\uc758 \uc704\uce58, \uba74\uc801, \uad6c\uc870, \uc6a9\ub3c4, \uce35\uc218, \uc0ac\uc6a9\uc2b9\uc778\uc77c \ub4f1\uc758 \uac74\ucd95\ubb3c \ud45c\uc2dc\uc5d0 \uad00\ud55c \uc0ac\ud56d\uacfc \uc18c\uc720\uc790 \uc131\uba85, \uc8fc\uc18c, \uc18c\uc720\uad8c \uc9c0\ubd84 \ub4f1\uc758 \uc18c\uc720\uc790 \ud604\ud669\uc5d0 \uad00\ud55c \uc0ac\ud56d\uc774 \ub4f1\ub85d\ub418\uc5b4 \uc788\uc2b5\ub2c8\ub2e4. \ubd80\ub3d9\uc0b0 \uac70\ub798\ub098 \ubd84\uc11d, \ub9ac\ubaa8\ub378\ub9c1 \uacc4\ud68d \uc2dc \uc911\uc694\ud55c \ucc38\uace0 \uc790\ub8cc\ub85c \uc0ac\uc6a9\ub429\ub2c8\ub2e4. [\ucd9c\ucc98: https://circle2.tistory.com/entry/\uac74\ucd95\ubb3c\ub300\uc7a5-\uc644\ubcbd-\uac00\uc774\ub4dc-\uc5f4\ub78c\ubd80\ud130-\ud65c\uc6a9\uae4c\uc9c0-\ubaa8\ub4e0-\uac83\uc744-\uc54c\ub824\ub4dc\ub9bd\ub2c8\ub2e4]"
#                     },
#                     "parentId": "0b2b74b2-6973-4791-b83a-f7bb8e4d281e",
#                     "scores": [],
#                     "startTime": "2024-08-02T07:48:31.969",
#                     "tags": null,
#                     "threadId": "1f800824-8c2f-4d1f-86fb-0bcbc580577f",
#                     "type": "assistant_message"
#                 }
#             ],
#             "tags": null
#         },
#         {
#             "createdAt": "2024-08-02T07:40:49.678Z",
#             "id": "0c8ff286-9c63-4239-96f9-445df90d3b8f",
#             "metadata": {
#                 "chat_profile": null,
#                 "chat_settings": {},
#                 "client_type": "webapp",
#                 "http_referer": "http://localhost:8000/"
#             },
#             "name": "\uc548\ub155?",
#             "participant": {
#                 "id": "e03188a4-7c06-4da4-b26f-4cade142a733",
#                 "identifier": "jeongyun.2ee@gmail.com"
#             },
#             "steps": [
#                 {
#                     "attachments": [],
#                     "endTime": "2024-08-02T07:40:44.277",
#                     "error": null,
#                     "generation": null,
#                     "id": "b778ae8d-5cf5-4e96-9cf4-cb73380392c6",
#                     "input": null,
#                     "metadata": {
#                         "language": null,
#                         "showInput": null,
#                         "waitForAnswer": false
#                     },
#                     "name": "jeongyun.2ee@gmail.com",
#                     "output": {
#                         "content": "\uc548\ub155?"
#                     },
#                     "parentId": null,
#                     "scores": [],
#                     "startTime": "2024-08-02T07:40:44.277",
#                     "tags": null,
#                     "threadId": "0c8ff286-9c63-4239-96f9-445df90d3b8f",
#                     "type": "user_message"
#                 },
#                 {
#                     "attachments": [],
#                     "endTime": "2024-08-02T07:40:49.258",
#                     "error": null,
#                     "generation": null,
#                     "id": "3f71a6ec-360e-4fde-81e0-685bac80f58e",
#                     "input": {
#                         "content": "\uc548\ub155?"
#                     },
#                     "metadata": {
#                         "language": null,
#                         "showInput": "json",
#                         "waitForAnswer": null
#                     },
#                     "name": "on_message",
#                     "output": null,
#                     "parentId": "b778ae8d-5cf5-4e96-9cf4-cb73380392c6",
#                     "scores": [
#                         {
#                             "comment": "\uce5c\uc808\ud574!",
#                             "datasetExperimentItemId": "",
#                             "generationId": "",
#                             "id": "dd33c92d-2061-4964-9ea9-b628b1555297",
#                             "name": "user-feedback",
#                             "stepId": "",
#                             "tags": [],
#                             "type": "HUMAN",
#                             "value": 1.0
#                         }
#                     ],
#                     "startTime": "2024-08-02T07:40:44.28",
#                     "tags": null,
#                     "threadId": "0c8ff286-9c63-4239-96f9-445df90d3b8f",
#                     "type": "run"
#                 },
#                 {
#                     "attachments": [],
#                     "endTime": "2024-08-02T07:40:49.239",
#                     "error": null,
#                     "generation": null,
#                     "id": "71cf665c-8411-41c1-b324-6f7b13fdd9c6",
#                     "input": null,
#                     "metadata": {
#                         "language": null,
#                         "showInput": null,
#                         "waitForAnswer": false
#                     },
#                     "name": "Assistant",
#                     "output": {
#                         "content": "\uc548\ub155\ud558\uc138\uc694! \ubb34\uc5c7\uc744 \ub3c4\uc640\ub4dc\ub9b4\uae4c\uc694?"
#                     },
#                     "parentId": "3f71a6ec-360e-4fde-81e0-685bac80f58e",
#                     "scores": [],
#                     "startTime": "2024-08-02T07:40:49.239",
#                     "tags": null,
#                     "threadId": "0c8ff286-9c63-4239-96f9-445df90d3b8f",
#                     "type": "assistant_message"
#                 }
#             ],
#             "tags": null
#         }
#     ],
#     "pageInfo": {
#         "endCursor": "R1BDOlM6MGM4ZmYyODYtOWM2My00MjM5LTk2ZjktNDQ1ZGY5MGQzYjhm",
#         "hasNextPage": false,
#         "startCursor": "R1BDOlM6YTExNWYyYzEtOWI5MC00N2ZjLWI3M2YtOTAzNGFjNGRjNjk3"
#     },
#     "totalCount": 179
# }

# %% [markdown]
# ## tmp test

# %%
import os
import json
import pprint
from dotenv import load_dotenv
## langsmith
from langsmith import Client
from langchain_teddynote import logging
## OpenAI
from langchain_openai import ChatOpenAI
from langchain.schema import ChatMessage, AIMessage, HumanMessage, SystemMessage
# from langchain.embeddings.openai import OpenAIEmbeddings
from langchain_community.embeddings import OpenAIEmbeddings
from langchain_openai import OpenAIEmbeddings
## ChromaDB
import chromadb
# from langchain.vectorstores import Chroma
from langchain_community.vectorstores import Chroma
## History
from operator import itemgetter
from langchain_core.prompts import PromptTemplate
from langchain_core.runnables import RunnableConfig
from langchain_core.output_parsers import StrOutputParser
from langchain_core.prompts import ChatPromptTemplate, MessagesPlaceholder
from langchain_community.chat_message_histories import ChatMessageHistory, StreamlitChatMessageHistory
from langchain_core.runnables.history import RunnableWithMessageHistory
## LangGraph
from typing import TypedDict
from langgraph.graph import END, StateGraph
from langgraph.checkpoint.memory import MemorySaver
from langgraph.errors import GraphRecursionError
from langchain_community.tools.tavily_search import TavilySearchResults
## chainlit
import chainlit as cl
from typing import Dict, Optional
## literaliteral_client
from literalai import LiteralClient

# .env 파일 활성화 & API KEY 설정
load_dotenv(override=True)
openai_api_key = os.getenv('OPENAI_API_KEY')

logging.langsmith("240731") 

literal_client = LiteralClient(api_key=os.getenv("LITERAL_API_KEY"))
literal_client.instrument_openai()

##############################################################################################################
##############################################################################################################
##############################################################################################################

admin_id = os.getenv("ADMIN_ID")
admin_pw = os.getenv("ADMIN_PW")

tester_id = os.getenv("TESTER_ID")
tester_pw = os.getenv("TESTER_PW")

# @cl.password_auth_callback
# def auth_callback(username: str, password: str):
#     # Fetch the user matching username from your database
#     # and compare the hashed password with the value stored in the database
#     if (username, password) == (admin_id, admin_pw):
#         return cl.User(
#             identifier="admin", metadata={"role": "admin", "provider": "credentials"}
#         )
#     elif (username, password) == ('tester', 'tester'):
#         return cl.User(
#             identifier="tester", metadata={"role": "user", "provider": "credentials"}
#         )
#     elif (username, password) == ('haklaekim', 'haklaekim'):
#         return cl.User(
#             identifier="haklaekim", metadata={"role": "user", "provider": "credentials"}
#         )
#     elif (username, password) == ('jeongyunlee', 'jeongyunlee'):
#         return cl.User(
#             identifier="jeongyunlee", metadata={"role": "user", "provider": "credentials"}
#         )
#     elif (username, password) == ('harampark', 'harampark'):
#         return cl.User(
#             identifier="harampark", metadata={"role": "user", "provider": "credentials"}
#         )
#     elif (username, password) == ('chaeeunsong', 'chaeeunsong'):
#         return cl.User(
#             identifier="chaeeunsong", metadata={"role": "user", "provider": "credentials"}
#         )
#     elif (username, password) == ('jieunahn', 'jieunahn'):
#         return cl.User(
#             identifier="jieunahn", metadata={"role": "user", "provider": "credentials"}
#         )
#     elif (username, password) == ('yejunpark', 'yejunpark'):
#         return cl.User(
#             identifier="yejunpark", metadata={"role": "user", "provider": "credentials"}
#         )
#     elif (username, password) == ('eunhyechoi', 'eunhyechoi'):
#         return cl.User(
#             identifier="eunhyechoi", metadata={"role": "user", "provider": "credentials"}
#         )
#     elif (username, password) == ('youngkyukim', 'youngkyukim'):
#         return cl.User(
#             identifier="youngkyukim", metadata={"role": "user", "provider": "credentials"}
#         )
#     else:
#         return None
    
# @cl.oauth_callback
# def oauth_callback(
#   provider_id: str,
#   token: str,
#   raw_user_data: Dict[str, str],
#   default_user: cl.User,
# ) -> Optional[cl.User]:
#   return default_user

@cl.set_starters
async def set_starters():

    return [
        cl.Starter(
            label="도로명주소의 정의를 알려줘",
            message="도로명주소의 정의를 알려줘",
            icon="/public/idea.svg",
            ),
        cl.Starter(
            label="특례시의 정의가 뭐야?",
            message="특례시가 뭐야?",
            icon="/public/terminal.svg",
            ),
        cl.Starter(
            label="주소와 주소정보의 차이를 알려줘",
            message="주소와 주소정보의 차이를 알려줘",
            icon="/public/learn.svg",
            ),
        cl.Starter(
            label="도로명주소가 도입된 연도는?",
            message="도로명주소가 도입된 연도는?",
            icon="/public/write.svg",
            )
        ]

##############################################################################################################
################################################GraphState####################################################
##############################################################################################################
# GraphState 상태를 저장하는 용도
class GraphState(TypedDict):
    question: str  # 질문
    q_type: str # 질문의 유형
    context: str  # 문서의 검색 결과
    answer: str  # llm이 생성한 답변
    relevance: str  # 답변의 문서에 대한 관련성 (groundness check)
    
store = {}

# 세션 ID를 기반으로 세션 기록을 가져오는 함수
def get_session_history(session_ids):
    if session_ids not in store:  # 세션 ID가 store에 없는 경우
        # 새로운 ChatMessageHistory 객체를 생성하여 store에 저장
        store[session_ids] = ChatMessageHistory()
    return store[session_ids]  # 해당 세션 ID에 대한 세션 기록 반환

##############################################################################################################
################################################Decision Maker ###############################################
##############################################################################################################

def decision_maker(state: GraphState) -> GraphState:
    chat = ChatOpenAI(model="gpt-4o", api_key=openai_api_key)
    
    prompt = PromptTemplate.from_template(
         """
            너는 question의 종류를 분류하는 모델이야. 질문의 종류는 ['주소관련 질문', '검색필요 질문', '일반 질문'] 3가지 종류로 구분 돼. 이때 question뿐만 아니라 chat_history까지 고려해줘.
            
            1. 주소관련 질문: 주소(address)와 관련된 질문을 의미해. 예를 들어, 주소와 관련된 개념, 정의, 주소관련 데이터 분석 등과 같은 내용의 질문일 경우 '주소관련 질문'으로 분류해 줘.
            2. 검색필요 질문: 주소(address)와 관련되지 않은 질문 중, 너가 스스로 대답할 수 없는 질문을 의미해. 예를 들어, '오늘의 날씨', '오늘의 주가' 등과 같이 최신 정보를 반영해야 하는 경우와 '~검색해줘'라는 말이 포함될 때 '검색필요 질문'으로 분류해 줘.
            3. 일반 질문: 주소(address)와 관련되지 않은 질문 중, 너가 스스로 대답할 수 있는 질문을 의미해. 예를 들어, '영어를 한국어로 번역해줘', '대한민국의 수도는?'과 같이 일반 상식적인 질문인 경우 '일반 질문'으로 분류해 줘.
            
            질문이 들어왔을 때, 위 3개의 종류 중에 가장 해당되는 분류를 선택하고 반드시 ['주소관련 질문', '검색필요 질문', '일반 질문'] 중 하나로 선택해. 띄어쓰기나 대소문자 구분 등 다른 형식이나 추가적인 설명 없이 오직 하나의 라벨만 출력해줘.

            #Previous Chat History:
            {chat_history}

            #Question: 
            {question} 
            #Answer:"""
            )
    
    chain = prompt | chat | StrOutputParser()
    
    rag_with_history = RunnableWithMessageHistory(
        chain,
        get_session_history,  # 세션 기록을 가져오는 함수
        input_messages_key="question",  # 사용자의 질문이 템플릿 변수에 들어갈 key
        history_messages_key="chat_history",  # 기록 메시지의 키
    )
    
    input_data = {
        'question': state["question"],
        'chat_history': itemgetter("chat_history"),
        'context':''
    }
    
    response = rag_with_history.invoke(input_data, config={"configurable": {"session_id": "rag123"}})
    return GraphState(
        q_type=response,
        question=state["question"],
    )

def decision_making(state: GraphState) -> GraphState:
    q_type_strip = state["q_type"].strip()
    if q_type_strip == "주소관련 질문":
        return "about_address"
    elif q_type_strip == "검색필요 질문":
        return "search"
    elif q_type_strip == "일반 질문":
        return "general"
    

##############################################################################################################
################################################Groundness Checker ###########################################
##############################################################################################################

chat = ChatOpenAI(model="gpt-4o", api_key=openai_api_key)

def relevance_message(context, question):
    
    messages = [
        SystemMessage(content="""
            너는 Query와 Document를 비교해서 ['grounded', 'notGrounded', 'notSure'] 셋 중 하나의 라벨을 출력하는 모델이야.

            'grounded': Compare the Query and the Document. If the Document includes content that can be used to generate an answer to the Query, output the label 'grounded'.
            'notGrounded': Compare the Query and the Document. If the Document does not include content that can be used to generate an answer to the Query, or if the information is insufficient, output the label ‘notGrounded’.
            'notSure': Compare the Query and the Document. If you cannot determine whether the Document includes content that can be used to generate an answer to the Query, output the label .notSure'.
            
            너의 출력은 반드시 'grounded', 'notGrounded', 'notSure' 중 하나여야 해. 띄어쓰기나 대소문자 구분 등 다른 형식이나 추가적인 설명 없이 오직 하나의 라벨만 출력해줘.
        """),
        HumanMessage(content=f"""
            [Document]
            {context}

            [Query]
            {question}
        """),
    ]
    return messages

def relevance_check(state: GraphState) -> GraphState:
    messages = relevance_message(state["context"], state["question"])

    response = chat.invoke(messages)
    return GraphState(
        relevance=response.content,
        context=state["context"],
        answer=state["answer"],
        question=state["question"],
    )

def is_relevant(state: GraphState) -> GraphState:
    relevance_strip = state["relevance"].strip()
    if relevance_strip == "grounded":
        return "grounded"
    elif relevance_strip == "notGrounded":
        return "notGrounded"
    elif relevance_strip == "notSure":
        return "notSure"
    

##############################################################################################################
################################################LLM Answer Maker##############################################
##############################################################################################################
def llm_answer(state: GraphState) -> GraphState:
    
    # 프롬프트를 생성합니다.
    prompt = PromptTemplate.from_template(
        """
                너는 Context의 정보를 반드시 활용해서 답변을 생성하는 챗봇이야. 
                이때, 답변은 Context에 정보가 있을 수도 있고, 없을 수도 있어. 
                Context의 정보로 답변을 생성할 수 있는 경우 해당 정보를 활용하고, 만약 Context의 정보로 답변을 유추조차 할 수 없는 경우, Context를 참고하지 말고 잘 모르겠다고 답변해줘.
                답변에는 Context라는 단어를 사용하지 말아줘.
                
                만약 Context의 정보를 활용한다면, 출처를 알 수 있는 경우 출처(data/final, data/csv 등) 뒤에 있는 파일명을 적어주거나 '- url:' 뒤에서 'http:', 'https' 등으로 시작하는 url 주소 전체를 마지막에 넣어줘. 하지만 잘 모르겠다면 빼도 돼. 
                파일명을 출처로 작성한다면 'data/final', 'data/csv' 와 같은 경로명이나 .csv, .docx, .pdf, .txt 등 파일 경로와 확장자는 제거해줘. 
                파일명에 'chapter'가 포함된다면, 앞에 '주소 데이터 활용 설명서-'를 붙여줘.
                
                출처 기입 형식은 '(출처: )' 이렇게 써줘. 예시는 다음과 같아.
                
                1. (출처: 도로명주소법, 주소 데이터 활용 설명서-chapter3-2)
                2. (출처: https://www.juso.go.kr/CommonPageLink.do?link=/street/GuideBook, https://www.gov.kr/main?a=AA020InfoCappViewApp&HighCtgCD=&CappBizCD=15000000098)
                #Previous Chat History:
                {chat_history}

                #Question: 
                {question} 

                #Context: 
                {context} 

                #Answer:
                
            """
                )

    llm = ChatOpenAI(model_name="gpt-4o", temperature=0)
    
    # 프롬프트, 모델, 출력 파서를 체이닝합니다.
    chain = prompt | llm | StrOutputParser()

    # 대화를 기록하는 RAG 체인 생성
    rag_with_history = RunnableWithMessageHistory(
        chain,
        get_session_history,  # 세션 기록을 가져오는 함수
        input_messages_key="question",  # 사용자의 질문이 템플릿 변수에 들어갈 key
        history_messages_key="chat_history",  # 기록 메시지의 키
    )
    
    # 상태에서 질문과 대화 기록을 가져옵니다.
    input_data = {
        'question': state["question"],
        'chat_history': itemgetter("chat_history"),
        'context': state["context"]
    }

    response = rag_with_history.invoke(input_data, config={"configurable": {"session_id": "rag123"}})
    
    return GraphState(
        answer=response,
        context=state["context"],
        question=state["question"],
    )


##############################################################################################################
#############################################General LLM Answer Maker#########################################
##############################################################################################################
def general_llm(state: GraphState) -> GraphState:
    
    # 프롬프트를 생성합니다.
    prompt = PromptTemplate.from_template(
        """     
                너는 일반적인 상식과 정보에 대해서 답변하는 챗봇이야. chat_hisotry에 값이 있는 경우 그 값을 참고해서 답변을 해줘.

                #Previous Chat History:
                {chat_history}

                #Question: 
                {question} 
                
                #Answer:
                
            """
                )

    llm = ChatOpenAI(model_name="gpt-4o", temperature=0)
    
    # 프롬프트, 모델, 출력 파서를 체이닝합니다.
    chain = prompt | llm | StrOutputParser()

    # 대화를 기록하는 RAG 체인 생성
    rag_with_history = RunnableWithMessageHistory(
        chain,
        get_session_history,  # 세션 기록을 가져오는 함수
        input_messages_key="question",  # 사용자의 질문이 템플릿 변수에 들어갈 key
        history_messages_key="chat_history",  # 기록 메시지의 키
    )
    
    # 상태에서 질문과 대화 기록을 가져옵니다.
    input_data = {
        'question': state["question"],
        'chat_history': itemgetter("chat_history"),
    }

    response = rag_with_history.invoke(input_data, config={"configurable": {"session_id": "rag123"}})
    return GraphState(
        answer=response,
        question=state["question"],
    )
    
##############################################################################################################
################################################Retriever#####################################################
##############################################################################################################
class MultiCollectionRetriever:
    def __init__(self, client, collection_names, embedding_function, search_kwargs={"k": 2}):
        self.collections = [
            Chroma(client=client, collection_name=name, embedding_function=embedding_function)
            for name in collection_names
        ]
        self.search_kwargs = search_kwargs

    def retrieve(self, query):
        results = []
        for collection in self.collections:
            # 각 컬렉션에서 유사도 검색 수행
            documents_with_scores = collection.similarity_search_with_score(query, **self.search_kwargs)
            results.extend(documents_with_scores)
        
        # 유사도 점수를 기준으로 결과 정렬 (score가 높을수록 유사도가 높음)
        results.sort(key=lambda x: x[1], reverse=False)

        documents = [(doc, score) for doc, score in results]
        return documents

# 사용 예시
client = chromadb.PersistentClient('chroma/')
collection_names = ["csv_files_openai_3072", "49_files_openai_3072"]
embedding = OpenAIEmbeddings(model='text-embedding-3-large') 
multi_retriever = MultiCollectionRetriever(client, collection_names, embedding)

##############################################################################################################
################################################vector Retriever##############################################
##############################################################################################################

def retrieve_document(state: GraphState) -> GraphState:
    # Question 에 대한 문서 검색을 retriever 로 수행합니다.
    retrieved_docs = multi_retriever.retrieve(state["question"])
    # 검색된 문서를 context 키에 저장합니다.
    return GraphState(context=retrieved_docs[:2])

##############################################################################################################
################################################Search on Web ################################################
##############################################################################################################  
    
def search_on_web(state: GraphState) -> GraphState:
    # 문서에서 검색하여 관련성 있는 문서를 찾습니다.
    search_tool = TavilySearchResults(max_results=5)
    search_result = search_tool.invoke({"query": state["question"]})

    # 검색된 문서를 context 키에 저장합니다.
    return GraphState(
        context=search_result,
    )
    
##############################################################################################################
################################################Setting Graph Relations#######################################
##############################################################################################################

workflow = StateGraph(GraphState)

# 노드들을 정의합니다.
workflow.add_node("decision_maker", decision_maker)  # 질문의 종류를 분류하는 노드를 추가합니다.
workflow.add_node("retrieve", retrieve_document)  # 답변을 검색해오는 노드를 추가합니다.
workflow.add_node("general_llm", general_llm)  # 일반 질문에 대한 답변을 생성하는 노드를 추가합니다.
workflow.add_node("relevance_check", relevance_check)  # 답변의 문서에 대한 관련성 체크 노드를 추가합니다.
workflow.add_node("search_on_web", search_on_web)  # 웹 검색 노드를 추가합니다.
workflow.add_node("llm_answer", llm_answer)  # 답변을 생성하는 노드를 추가합니다.

workflow.add_edge("retrieve", "relevance_check")  # 검색 -> 답변
workflow.add_edge("search_on_web", "relevance_check")  # 웹 검색 -> 답변

# 조건부 엣지를 추가합니다.
workflow.add_conditional_edges(
    "decision_maker",  # 관련성 체크 노드에서 나온 결과를 is_relevant 함수에 전달합니다.
    decision_making,
    {
        "about_address": "retrieve",  # 관련성이 있으면 종료합니다.
        "search": "search_on_web",  # 관련성이 없으면 다시 질문을 작성합니다.
        "general": "general_llm",  # 관련성 체크 결과가 모호하다면 다시 질문을 작성합니다.
    },
)

# 조건부 엣지를 추가합니다.
workflow.add_conditional_edges(
    "relevance_check",  # 관련성 체크 노드에서 나온 결과를 is_relevant 함수에 전달합니다.
    is_relevant,
    {
        "grounded": "llm_answer",  # 관련성이 있으면 종료합니다.
        "notGrounded": "search_on_web",  # 관련성이 없으면 다시 질문을 작성합니다.
        "notSure": "search_on_web",  # 관련성 체크 결과가 모호하다면 다시 질문을 작성합니다.
    },
)

workflow.add_edge("llm_answer", END)  # 답변 -> 종료
workflow.add_edge("general_llm", END)  # 답변 -> 종료

# 시작점을 설정합니다.
workflow.set_entry_point("decision_maker")

# 기록을 위한 메모리 저장소를 설정합니다.
memory = MemorySaver()

# 그래프를 컴파일합니다.
app = workflow.compile(checkpointer=memory)

##############################################################################################################
################################################Chat Interface################################################
##############################################################################################################

query = "hi"

config = RunnableConfig(
    recursion_limit=20, configurable={"thread_id": "CORRECTIVE-SEARCH-RAG"}
)

inputs = GraphState(
    question=query
)

try:
    answer = app.stream(inputs, config=config)
    print(answer)
    answer_text = answer['answer']
    
except GraphRecursionError as e:
    print(f"Recursion limit reached: {e}")
    answer_text = "죄송합니다. 해당 질문에 대해서는 답변할 수 없습니다."
except Exception as e:
    print(f"An error occurred: {e}")
    answer_text = "죄송합니다. 처리 중 오류가 발생했습니다."
# Out:
# LangSmith 추적을 시작합니다.
# [프로젝트명]
# 240731
# 2024-08-07 12:09:22 - Collection csv_files_openai_3072 is not created.
# 2024-08-07 12:09:22 - Collection 49_files_openai_3072 is not created.
# <generator object Pregel.stream at 0x17c4952b0>
# An error occurred: 'generator' object is not subscriptable

# %%
answer = app.stream({'question':'hi'}, config=config)
final_answer = list(answer)
# Out:
# 2024-08-07 12:09:56 - Error in RootListenersTracer.on_chain_end callback: KeyError('message_history')
# 2024-08-07 12:09:56 - Error in callback coroutine: KeyError('message_history')
# 2024-08-07 12:09:56 - Error in RootListenersTracer.on_chain_end callback: KeyError('message_history')
# 2024-08-07 12:09:56 - Error in callback coroutine: KeyError('message_history')
# 2024-08-07 12:09:57 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-08-07 12:09:59 - HTTP Request: POST https://cloud.getliteral.ai/api/graphql "HTTP/1.1 200 OK"
# 2024-08-07 12:09:59 - Error in RootListenersTracer.on_chain_end callback: KeyError('message_history')
# 2024-08-07 12:09:59 - Error in callback coroutine: KeyError('message_history')
# 2024-08-07 12:09:59 - Error in RootListenersTracer.on_chain_end callback: KeyError('message_history')
# 2024-08-07 12:09:59 - Error in callback coroutine: KeyError('message_history')
# 2024-08-07 12:10:00 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-08-07 12:10:01 - HTTP Request: POST https://cloud.getliteral.ai/api/graphql "HTTP/1.1 200 OK"

# %%
final_answer
# Out:
# {'general_llm': {'question': 'hi',
#   'answer': '안녕하세요! 무엇을 도와드릴까요? 일반적인 상식이나 정보에 대해 질문해주시면 답변해드리겠습니다.'}}

# %%
if 'general_llm' in final_answer[-1]:
    answer_text = final_answer[-1]['general_llm']['answer']
# llm_answer 키가 존재하는지 확인
elif 'llm_answer' in final_answer[-1]:
    answer_text = final_answer[-1]['llm_answer']['answer']

answer_text
# Out:
# '안녕하세요! 무엇을 도와드릴까요? 일반적인 상식이나 정보에 대해 질문해주시면 답변해드리겠습니다.'

# %%
final_answer[0].keys()
# Out:
# dict_keys(['decision_maker'])

# %%
final_answer[0].values()
# Out:
# dict_values([{'question': '도로명주소의 정의는?', 'q_type': '주소관련 질문'}])

# %%
final_answer[1]
# Out:
# {'retrieve': {'context': [(Document(metadata={'source': 'data/final/[1018] 주소정보_업무편람_최종(하이퍼링크).docx'}, page_content='가. 주소에서 주소정보로의 확대\n\n1) 주소의 기능\n\n주소는 사람이나 법인의 주된 거주지(소재지)를 주민등록(법인등록)에 등록하는 데 주로 사용해 왔고 ‘생활의 근거가 되는 곳’으로 거처(居處) 또는 거지(居趾)의 의미를 담아 우편 배송이나 위치 찾기에 사용되어 왔음.\n\n2) 주소에 대한 사회적 수요의 변화\n\n주소는 사람을 구분하여 등록하거나 집을 찾는 데 사용되어 왔으나 도시의 변화 등에 따라 집 찾기에서 방 찾기로 기대 수준이 높아졌고, 사람이 있는 모든 접점에 대한 주소표시의 수요가 발생\n\n3) 주소정보의 등장\n\n주소정보는 주된 소재지라는 주소의 공·사법적 역할에서 벗어나 모든 접점에 대한 위치표시로 확대하기 위하여 도입\n\n국제표준화기구(ISO)에서도 주소 국제표준(ISO 19160-1)을 제정하면서 address를 ‘식별 및 위치 파악을 목적으로 단일 객체를 명확하게 확인할 수 있게 하는 구조화된 정보’로 정의\n\n나. 주소정보의 의의'),
#     0.8635082840919495),
#    (Document(metadata={'author': 'DUoffice', 'creationDate': "D:20240618015036Z00'00'", 'creator': '한컴오피스 한글 2018', 'file_path': 'data/final/주소체계 고도화에 따른 주소정보 개념 정립 연구.pdf', 'format': 'PDF 1.3', 'keywords': '', 'modDate': "D:20240618015036Z00'00'", 'page': 24, 'producer': 'macOS Version 14.5 (Build 23F79) Quartz PDFContext', 'source': 'data/final/주소체계 고도화에 따른 주소정보 개념 정립 연구.pdf', 'subject': '', 'title': '', 'total_pages': 246, 'trapped': ''}, page_content='의하고 있다. \n이에 주소정보와 관련된 용어정의를 위하여 본 연구에서는 국제표준을 \n국문화한 KS X ISO 19160-1:2015에서 정의하고 있는 용어들을 살펴보\n고자 한다(<표 2-1>). \n주소정보 개념 재정립\n용어\n정의\n주소(address) \n식별 및 위치 파악을 목적으로 단일 객체를 명확하게 \n확인할 수 있게 하는 구조화된 정보\n  식별 : 주소의 구조화된 정보가 명확하게 객체를 확인한다는 것. \n사람이 객체를 식별하는데 도움이 된다는 의미 \n(시스템(DB)에서 의미하는 고유한 식별자는 아님)\n  객체 : 실제 세계에서 식별이 가능한 것 (전자 및 가상은 제외)\n주소 부여 대상\n(addressable object)\n주소를 할당할 수 있는 객체\n<표 2-1> KS X ISO 19160-1:2015 내 용어 및 정의 재구성'),
#     0.8921937942504883)]}}

# %%
final_answer[2]
# Out:
# {'relevance_check': {'question': '도로명주소의 정의는?',
#   'context': [(Document(metadata={'source': 'data/final/[1018] 주소정보_업무편람_최종(하이퍼링크).docx'}, page_content='가. 주소에서 주소정보로의 확대\n\n1) 주소의 기능\n\n주소는 사람이나 법인의 주된 거주지(소재지)를 주민등록(법인등록)에 등록하는 데 주로 사용해 왔고 ‘생활의 근거가 되는 곳’으로 거처(居處) 또는 거지(居趾)의 의미를 담아 우편 배송이나 위치 찾기에 사용되어 왔음.\n\n2) 주소에 대한 사회적 수요의 변화\n\n주소는 사람을 구분하여 등록하거나 집을 찾는 데 사용되어 왔으나 도시의 변화 등에 따라 집 찾기에서 방 찾기로 기대 수준이 높아졌고, 사람이 있는 모든 접점에 대한 주소표시의 수요가 발생\n\n3) 주소정보의 등장\n\n주소정보는 주된 소재지라는 주소의 공·사법적 역할에서 벗어나 모든 접점에 대한 위치표시로 확대하기 위하여 도입\n\n국제표준화기구(ISO)에서도 주소 국제표준(ISO 19160-1)을 제정하면서 address를 ‘식별 및 위치 파악을 목적으로 단일 객체를 명확하게 확인할 수 있게 하는 구조화된 정보’로 정의\n\n나. 주소정보의 의의'),
#     0.8635082840919495),
#    (Document(metadata={'author': 'DUoffice', 'creationDate': "D:20240618015036Z00'00'", 'creator': '한컴오피스 한글 2018', 'file_path': 'data/final/주소체계 고도화에 따른 주소정보 개념 정립 연구.pdf', 'format': 'PDF 1.3', 'keywords': '', 'modDate': "D:20240618015036Z00'00'", 'page': 24, 'producer': 'macOS Version 14.5 (Build 23F79) Quartz PDFContext', 'source': 'data/final/주소체계 고도화에 따른 주소정보 개념 정립 연구.pdf', 'subject': '', 'title': '', 'total_pages': 246, 'trapped': ''}, page_content='의하고 있다. \n이에 주소정보와 관련된 용어정의를 위하여 본 연구에서는 국제표준을 \n국문화한 KS X ISO 19160-1:2015에서 정의하고 있는 용어들을 살펴보\n고자 한다(<표 2-1>). \n주소정보 개념 재정립\n용어\n정의\n주소(address) \n식별 및 위치 파악을 목적으로 단일 객체를 명확하게 \n확인할 수 있게 하는 구조화된 정보\n  식별 : 주소의 구조화된 정보가 명확하게 객체를 확인한다는 것. \n사람이 객체를 식별하는데 도움이 된다는 의미 \n(시스템(DB)에서 의미하는 고유한 식별자는 아님)\n  객체 : 실제 세계에서 식별이 가능한 것 (전자 및 가상은 제외)\n주소 부여 대상\n(addressable object)\n주소를 할당할 수 있는 객체\n<표 2-1> KS X ISO 19160-1:2015 내 용어 및 정의 재구성'),
#     0.8921937942504883)],
#   'answer': '도로명주소는 부여된 도로명, 기초번호, 건물번호, 상세주소에 의하여 건물의 주소를 표기하는 방식입니다. 도로에는 도로명을 부여하고, 건물에는 도로에 따라 규칙적으로 건물번호를 부여하여 도로명과 건물번호로 주소를 구성합니다. (출처: https://www.juso.go.kr/CommonPageLink.do?link=/street/GuideBook)',
#   'relevance': 'notGrounded'}}

# %%
final_answer[-1]['llm_answer']['answer']
# Out:
# "도로명주소는 대한민국에서 1995년부터 시범사업을 시작하여 2009년 전면 개정, 2014년 전면 시행된 주소 표기 방법 중 하나입니다. 도로명을 주소 표기에 사용하기 때문에 '도로명주소'가 정식 명칭입니다. 행정안전부에서 관장합니다. (출처: https://namu.wiki/w/도로명주소)"

# %%
final_answer[1].keys()
# Out:
# dict_keys(['retrieve'])

# %%
answer = app.stream(inputs, config=config)
final_answer = list(answer)

keys = []
[keys.append(list(final_answer[i].keys())[0]) for i in range(len(final_answer))]
# Out:
# ['decision_maker',
#  'retrieve',
#  'relevance_check',
#  'search_on_web',
#  'relevance_check',
#  'llm_answer']

# %%
keys = []
for output in app.stream(inputs, config=config):
    # 출력된 결과에서 키와 값을 순회합니다.
    for key, value in output.items():
        keys.append(key)

# %%
for output in app.stream(inputs, config=config):
    # 출력된 결과에서 키와 값을 순회합니다.
    for key, value in output.items():
        # 노드의 이름과 해당 노드에서 나온 출력을 출력합니다.
        pprint.pprint(f"Output from node '{key}':")
        pprint.pprint("---")
        # 출력 값을 예쁘게 출력합니다.
        # pprint.pprint(value, indent=2, width=80, depth=None)
    # 각 출력 사이에 구분선을 추가합니다.
    pprint.pprint("\n---\n")
# Out:
# 2024-08-07 11:46:09 - Error in RootListenersTracer.on_chain_end callback: KeyError('message_history')
# 2024-08-07 11:46:09 - Error in callback coroutine: KeyError('message_history')
# 2024-08-07 11:46:09 - Error in RootListenersTracer.on_chain_end callback: KeyError('message_history')
# 2024-08-07 11:46:09 - Error in callback coroutine: KeyError('message_history')
# 2024-08-07 11:46:09 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-08-07 11:46:12 - HTTP Request: POST https://cloud.getliteral.ai/api/graphql "HTTP/1.1 200 OK"
# "Output from node 'decision_maker':"
# '---'
# '\n---\n'
# 2024-08-07 11:46:12 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-08-07 11:46:12 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# "Output from node 'retrieve':"
# '---'
# '\n---\n'
# 2024-08-07 11:46:13 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-08-07 11:46:15 - HTTP Request: POST https://cloud.getliteral.ai/api/graphql "HTTP/1.1 200 OK"
# "Output from node 'relevance_check':"
# '---'
# '\n---\n'
# 2024-08-07 11:46:15 - Error in RootListenersTracer.on_chain_end callback: KeyError('message_history')
# 2024-08-07 11:46:15 - Error in callback coroutine: KeyError('message_history')
# 2024-08-07 11:46:15 - Error in RootListenersTracer.on_chain_end callback: KeyError('message_history')
# 2024-08-07 11:46:15 - Error in callback coroutine: KeyError('message_history')
# 2024-08-07 11:46:17 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-08-07 11:46:19 - HTTP Request: POST https://cloud.getliteral.ai/api/graphql "HTTP/1.1 200 OK"
# "Output from node 'llm_answer':"
# '---'
# '\n---\n'

# %%
tmp = '''
[{'retrieve': {'context': [(Document(metadata={'source': 'data/final/[1018] 주소정보_업무편람_최종(하이퍼링크).docx'}, page_content='제2절 주소정보 개념\n\n\n가. 사전적 의미\n\n1) 국어사전\n\n사람 또는 기업이 살거나 소재하고 있는 곳\n\n사람이 살고 있는 곳이나 기관, 회사 따위가 자리 잡고 있는 곳을 행정구역으로 나타낸 이름\n\n관련 용어\n\n거소(居所) : 얼마간 계속 머물러 있는 장소\n\n가주소(假住所) : 어느 행위에 있어서, 주소 이외의 장소에 주소로서의 법률적 효과를 부여하기 위해 당사자가 선정한 장소\n\n2) 영어사전\n\n사람이나 조직이 연락 가능한 장소(a place where a person or organization may be communicated with)\n\n편지나 소포 등의 겉봉에 있는 배달지(direction for delivery on the outside of an object as a letter or package)\n\n\n\n나. 법률적 의미\n\n1) 민법 : 생활근거지 또는 사업장 소재지를 의미\n\n생활의 근거가 되는 곳(법 §18①)'),
     0.8956763744354248),
    (Document(metadata={'source': 'data/final/[1018] 주소정보_업무편람_최종(하이퍼링크).docx'}, page_content='3) 우편법\n\n우편물은 그 표면에 기재된 곳에 배달함(법 §31)\n\n4) 도로명주소법\n\n“도로명주소”라 함은 도로명, 건물번호 및 상세주소(상세주소가 있는 경우만 해당한다)로 표기하는 주소를 말함(법 §2제7호)\n\n이 법은 주소의 적용에 관한 사항에 있어 다른 법률에 우선함(법 §3)\n\n공법관계의 주소는 도로명주소로 함. 따라서 공공기관은 주소의 표기 및 위치 안내에 있어 도로명주소를 사용해야 함(법 §19)\n\n가. 주소에서 주소정보로의 확대\n\n1) 주소의 기능\n\n주소는 사람이나 법인의 주된 거주지(소재지)를 주민등록(법인등록)에 등록하는 데 주로 사용해 왔고 ‘생활의 근거가 되는 곳’으로 거처(居處) 또는 거지(居趾)의 의미를 담아 우편 배송이나 위치 찾기에 사용되어 왔음.\n\n2) 주소에 대한 사회적 수요의 변화'),
     0.9399040937423706)]}},
 {'relevance_check': {'question': '도로명주소법 2조의 내용은?',
   'context': [(Document(metadata={'source': 'data/final/[1018] 주소정보_업무편람_최종(하이퍼링크).docx'}, page_content='제2절 주소정보 개념\n\n\n가. 사전적 의미\n\n1) 국어사전\n\n사람 또는 기업이 살거나 소재하고 있는 곳\n\n사람이 살고 있는 곳이나 기관, 회사 따위가 자리 잡고 있는 곳을 행정구역으로 나타낸 이름\n\n관련 용어\n\n거소(居所) : 얼마간 계속 머물러 있는 장소\n\n가주소(假住所) : 어느 행위에 있어서, 주소 이외의 장소에 주소로서의 법률적 효과를 부여하기 위해 당사자가 선정한 장소\n\n2) 영어사전\n\n사람이나 조직이 연락 가능한 장소(a place where a person or organization may be communicated with)\n\n편지나 소포 등의 겉봉에 있는 배달지(direction for delivery on the outside of an object as a letter or package)\n\n\n\n나. 법률적 의미\n\n1) 민법 : 생활근거지 또는 사업장 소재지를 의미\n\n생활의 근거가 되는 곳(법 §18①)'),
     0.8956763744354248),
    (Document(metadata={'source': 'data/final/[1018] 주소정보_업무편람_최종(하이퍼링크).docx'}, page_content='3) 우편법\n\n우편물은 그 표면에 기재된 곳에 배달함(법 §31)\n\n4) 도로명주소법\n\n“도로명주소”라 함은 도로명, 건물번호 및 상세주소(상세주소가 있는 경우만 해당한다)로 표기하는 주소를 말함(법 §2제7호)\n\n이 법은 주소의 적용에 관한 사항에 있어 다른 법률에 우선함(법 §3)\n\n공법관계의 주소는 도로명주소로 함. 따라서 공공기관은 주소의 표기 및 위치 안내에 있어 도로명주소를 사용해야 함(법 §19)\n\n가. 주소에서 주소정보로의 확대\n\n1) 주소의 기능\n\n주소는 사람이나 법인의 주된 거주지(소재지)를 주민등록(법인등록)에 등록하는 데 주로 사용해 왔고 ‘생활의 근거가 되는 곳’으로 거처(居處) 또는 거지(居趾)의 의미를 담아 우편 배송이나 위치 찾기에 사용되어 왔음.\n\n2) 주소에 대한 사회적 수요의 변화'),
     0.9399040937423706)],
   'answer': None,
   'relevance': 'grounded'}},
 {'llm_answer': {'question': '도로명주소법 2조의 내용은?',
   'context': [(Document(metadata={'source': 'data/final/[1018] 주소정보_업무편람_최종(하이퍼링크).docx'}, page_content='제2절 주소정보 개념\n\n\n가. 사전적 의미\n\n1) 국어사전\n\n사람 또는 기업이 살거나 소재하고 있는 곳\n\n사람이 살고 있는 곳이나 기관, 회사 따위가 자리 잡고 있는 곳을 행정구역으로 나타낸 이름\n\n관련 용어\n\n거소(居所) : 얼마간 계속 머물러 있는 장소\n\n가주소(假住所) : 어느 행위에 있어서, 주소 이외의 장소에 주소로서의 법률적 효과를 부여하기 위해 당사자가 선정한 장소\n\n2) 영어사전\n\n사람이나 조직이 연락 가능한 장소(a place where a person or organization may be communicated with)\n\n편지나 소포 등의 겉봉에 있는 배달지(direction for delivery on the outside of an object as a letter or package)\n\n\n\n나. 법률적 의미\n\n1) 민법 : 생활근거지 또는 사업장 소재지를 의미\n\n생활의 근거가 되는 곳(법 §18①)'),
     0.8956763744354248),
    (Document(metadata={'source': 'data/final/[1018] 주소정보_업무편람_최종(하이퍼링크).docx'}, page_content='3) 우편법\n\n우편물은 그 표면에 기재된 곳에 배달함(법 §31)\n\n4) 도로명주소법\n\n“도로명주소”라 함은 도로명, 건물번호 및 상세주소(상세주소가 있는 경우만 해당한다)로 표기하는 주소를 말함(법 §2제7호)\n\n이 법은 주소의 적용에 관한 사항에 있어 다른 법률에 우선함(법 §3)\n\n공법관계의 주소는 도로명주소로 함. 따라서 공공기관은 주소의 표기 및 위치 안내에 있어 도로명주소를 사용해야 함(법 §19)\n\n가. 주소에서 주소정보로의 확대\n\n1) 주소의 기능\n\n주소는 사람이나 법인의 주된 거주지(소재지)를 주민등록(법인등록)에 등록하는 데 주로 사용해 왔고 ‘생활의 근거가 되는 곳’으로 거처(居處) 또는 거지(居趾)의 의미를 담아 우편 배송이나 위치 찾기에 사용되어 왔음.\n\n2) 주소에 대한 사회적 수요의 변화'),
     0.9399040937423706)],
   'answer': '도로명주소법 제2조의 내용은 다음과 같습니다:\n\n"도로명주소"라 함은 도로명, 건물번호 및 상세주소(상세주소가 있는 경우만 해당한다)로 표기하는 주소를 말합니다.\n\n출처: 주소정보_업무편람_최종(하이퍼링크)'}}]
   '''
tmp
# Out:
# '\n[{\'retrieve\': {\'context\': [(Document(metadata={\'source\': \'data/final/[1018] 주소정보_업무편람_최종(하이퍼링크).docx\'}, page_content=\'제2절 주소정보 개념\n\n\n가. 사전적 의미\n\n1) 국어사전\n\n사람 또는 기업이 살거나 소재하고 있는 곳\n\n사람이 살고 있는 곳이나 기관, 회사 따위가 자리 잡고 있는 곳을 행정구역으로 나타낸 이름\n\n관련 용어\n\n거소(居所) : 얼마간 계속 머물러 있는 장소\n\n가주소(假住所) : 어느 행위에 있어서, 주소 이외의 장소에 주소로서의 법률적 효과를 부여하기 위해 당사자가 선정한 장소\n\n2) 영어사전\n\n사람이나 조직이 연락 가능한 장소(a place where a person or organization may be communicated with)\n\n편지나 소포 등의 겉봉에 있는 배달지(direction for delivery on the outside of an object as a letter or package)\n\n\n\n나. 법률적 의미\n\n1) 민법 : 생활근거지 또는 사업장 소재지를 의미\n\n생활의 근거가 되는 곳(법 §18①)\'),\n     0.8956763744354248),\n    (Document(metadata={\'source\': \'data/final/[1018] 주소정보_업무편람_최종(하이퍼링크).docx\'}, page_content=\'3) 우편법\n\n우편물은 그 표면에 기재된 곳에 배달함(법 §31)\n\n4) 도로명주소법\n\n“도로명주소”라 함은 도로명, 건물번호 및 상세주소(상세주소가 있는 경우만 해당한다)로 표기하는 주소를 말함(법 §2제7호)\n\n이 법은 주소의 적용에 관한 사항에 있어 다른 법률에 우선함(법 §3)\n\n공법관계의 주소는 도로명주소로 함. 따라서 공공기관은 주소의 표기 및 위치 안내에 있어 도로명주소를 사용해야 함(법 §19)\n\n가. 주소에서 주소정보로의 확대\n\n1) 주소의 기능\n\n주소는 사람이나 법인의 주된 거주지(소재지)를 주민등록(법인등록)에 등록하는 데 주로 사용해 왔고 ‘생활의 근거가 되는 곳’으로 거처(居處) 또는 거지(居趾)의 의미를 담아 우편 배송이나 위치 찾기에 사용되어 왔음.\n\n2) 주소에 대한 사회적 수요의 변화\'),\n     0.9399040937423706)]}},\n {\'relevance_check\': {\'question\': \'도로명주소법 2조의 내용은?\',\n   \'context\': [(Document(metadata={\'source\': \'data/final/[1018] 주소정보_업무편람_최종(하이퍼링크).docx\'}, page_content=\'제2절 주소정보 개념\n\n\n가. 사전적 의미\n\n1) 국어사전\n\n사람 또는 기업이 살거나 소재하고 있는 곳\n\n사람이 살고 있는 곳이나 기관, 회사 따위가 자리 잡고 있는 곳을 행정구역으로 나타낸 이름\n\n관련 용어\n\n거소(居所) : 얼마간 계속 머물러 있는 장소\n\n가주소(假住所) : 어느 행위에 있어서, 주소 이외의 장소에 주소로서의 법률적 효과를 부여하기 위해 당사자가 선정한 장소\n\n2) 영어사전\n\n사람이나 조직이 연락 가능한 장소(a place where a person or organization may be communicated with)\n\n편지나 소포 등의 겉봉에 있는 배달지(direction for delivery on the outside of an object as a letter or package)\n\n\n\n나. 법률적 의미\n\n1) 민법 : 생활근거지 또는 사업장 소재지를 의미\n\n생활의 근거가 되는 곳(법 §18①)\'),\n     0.8956763744354248),\n    (Document(metadata={\'source\': \'data/final/[1018] 주소정보_업무편람_최종(하이퍼링크).docx\'}, page_content=\'3) 우편법\n\n우편물은 그 표면에 기재된 곳에 배달함(법 §31)\n\n4) 도로명주소법\n\n“도로명주소”라 함은 도로명, 건물번호 및 상세주소(상세주소가 있는 경우만 해당한다)로 표기하는 주소를 말함(법 §2제7호)\n\n이 법은 주소의 적용에 관한 사항에 있어 다른 법률에 우선함(법 §3)\n\n공법관계의 주소는 도로명주소로 함. 따라서 공공기관은 주소의 표기 및 위치 안내에 있어 도로명주소를 사용해야 함(법 §19)\n\n가. 주소에서 주소정보로의 확대\n\n1) 주소의 기능\n\n주소는 사람이나 법인의 주된 거주지(소재지)를 주민등록(법인등록)에 등록하는 데 주로 사용해 왔고 ‘생활의 근거가 되는 곳’으로 거처(居處) 또는 거지(居趾)의 의미를 담아 우편 배송이나 위치 찾기에 사용되어 왔음.\n\n2) 주소에 대한 사회적 수요의 변화\'),\n     0.9399040937423706)],\n   \'answer\': None,\n   \'relevance\': \'grounded\'}},\n {\'llm_answer\': {\'question\': \'도로명주소법 2조의 내용은?\',\n   \'context\': [(Document(metadata={\'source\': \'data/final/[1018] 주소정보_업무편람_최종(하이퍼링크).docx\'}, page_content=\'제2절 주소정보 개념\n\n\n가. 사전적 의미\n\n1) 국어사전\n\n사람 또는 기업이 살거나 소재하고 있는 곳\n\n사람이 살고 있는 곳이나 기관, 회사 따위가 자리 잡고 있는 곳을 행정구역으로 나타낸 이름\n\n관련 용어\n\n거소(居所) : 얼마간 계속 머물러 있는 장소\n\n가주소(假住所) : 어느 행위에 있어서, 주소 이외의 장소에 주소로서의 법률적 효과를 부여하기 위해 당사자가 선정한 장소\n\n2) 영어사전\n\n사람이나 조직이 연락 가능한 장소(a place where a person or organization may be communicated with)\n\n편지나 소포 등의 겉봉에 있는 배달지(direction for delivery on the outside of an object as a letter or package)\n\n\n\n나. 법률적 의미\n\n1) 민법 : 생활근거지 또는 사업장 소재지를 의미\n\n생활의 근거가 되는 곳(법 §18①)\'),\n     0.8956763744354248),\n    (Document(metadata={\'source\': \'data/final/[1018] 주소정보_업무편람_최종(하이퍼링크).docx\'}, page_content=\'3) 우편법\n\n우편물은 그 표면에 기재된 곳에 배달함(법 §31)\n\n4) 도로명주소법\n\n“도로명주소”라 함은 도로명, 건물번호 및 상세주소(상세주소가 있는 경우만 해당한다)로 표기하는 주소를 말함(법 §2제7호)\n\n이 법은 주소의 적용에 관한 사항에 있어 다른 법률에 우선함(법 §3)\n\n공법관계의 주소는 도로명주소로 함. 따라서 공공기관은 주소의 표기 및 위치 안내에 있어 도로명주소를 사용해야 함(법 §19)\n\n가. 주소에서 주소정보로의 확대\n\n1) 주소의 기능\n\n주소는 사람이나 법인의 주된 거주지(소재지)를 주민등록(법인등록)에 등록하는 데 주로 사용해 왔고 ‘생활의 근거가 되는 곳’으로 거처(居處) 또는 거지(居趾)의 의미를 담아 우편 배송이나 위치 찾기에 사용되어 왔음.\n\n2) 주소에 대한 사회적 수요의 변화\'),\n     0.9399040937423706)],\n   \'answer\': \'도로명주소법 제2조의 내용은 다음과 같습니다:\n\n"도로명주소"라 함은 도로명, 건물번호 및 상세주소(상세주소가 있는 경우만 해당한다)로 표기하는 주소를 말합니다.\n\n출처: 주소정보_업무편람_최종(하이퍼링크)\'}}]\n   '
